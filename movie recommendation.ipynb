# %%
import pandas as pd
import numpy as np
import re
import nltk
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("movies_dataset.csv")
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated   Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14-Oct-94  142 min
# 1           2             The Godfather  1972         R  24-Mar-72  175 min
# 2           3    The Godfather: Part II  1974         R  20-Dec-74  202 min
# 3           4           The Dark Knight  2008     PG-13  18-Jul-08  152 min
# 4           5              12 Angry Men  1957  APPROVED  01-Apr-57   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3  18,25,626  tt0111161  movie
# 1        9.2/10      100.0         9.2  12,43,444  tt0068646  movie
# 2        9.0/10       85.0         9.0   8,56,870  tt0071562  movie
# 3        9.0/10       82.0         9.0  18,02,351  tt0468569  movie
# 4        8.9/10       96.0         8.9   4,94,215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#          DVD     BoxOffice                       Production  \
# 0  27-Jan-98           NaN                Columbia Pictures
# 1  09-Oct-01           NaN               Paramount Pictures
# 2  24-May-05           NaN               Paramount Pictures
# 3  09-Dec-08  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06-Mar-01           NaN             Criterion Collection
#
#                                              Website  Response
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True

# %%
df['Plot'][0]
# Out:
# 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'

# %%
df['clean_plot'] = df['Plot'].str.lower()
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('^a-zA-Z', ' ', x))
df['clean_plot'] = df['clean_plot'].apply(lambda x: re.sub('\s+', ' ', x))
df['clean_plot']
# Out:
# 0      two imprisoned men bond over a number of years...
# 1      the aging patriarch of an organized crime dyna...
# 2      the early life and career of vito corleone in ...
# 3      when the menace known as the joker emerges fro...
# 4      a jury holdout attempts to prevent a miscarria...
#                              ...
# 245    the desperate life of a chronic alcoholic is f...
# 246    a 20-something supervising staff member of a r...
# 247    a newspaper editor uses every trick in the boo...
# 248    an old man makes a long journey by lawn-mover ...
# 249    a mumbai teen reflects on his upbringing in th...
# Name: clean_plot, Length: 250, dtype: object

# %%
df['clean_plot'] = df['clean_plot'].apply(lambda x: nltk.word_tokenize(x))
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, over, a, number, ...
# 1      [the, aging, patriarch, of, an, organized, cri...
# 2      [the, early, life, and, career, of, vito, corl...
# 3      [when, the, menace, known, as, the, joker, eme...
# 4      [a, jury, holdout, attempts, to, prevent, a, m...
#                              ...
# 245    [the, desperate, life, of, a, chronic, alcohol...
# 246    [a, 20-something, supervising, staff, member, ...
# 247    [a, newspaper, editor, uses, every, trick, in,...
# 248    [an, old, man, makes, a, long, journey, by, la...
# 249    [a, mumbai, teen, reflects, on, his, upbringin...
# Name: clean_plot, Length: 250, dtype: object

# %%
stop_words = nltk.corpus.stopwords.words('english')
plot = []
for sentence in df['clean_plot']:
    temp = []
    for word in sentence:
        if word not in stop_words or len(word) >= 3:
            temp.append(word)
    plot.append(temp)
plot
# Out:
# [['two',
#   'imprisoned',
#   'men',
#   'bond',
#   'over',
#   'number',
#   'years',
#   ',',
#   'finding',
#   'solace',
#   'and',
#   'eventual',
#   'redemption',
#   'through',
#   'acts',
#   'common',
#   'decency',
#   '.'],
#  ['the',
#   'aging',
#   'patriarch',
#   'organized',
#   'crime',
#   'dynasty',
#   'transfers',
#   'control',
#   'his',
#   'clandestine',
#   'empire',
#   'his',
#   'reluctant',
#   'son',
#   '.'],
#  ['the',
#   'early',
#   'life',
#   'and',
#   'career',
#   'vito',
#   'corleone',
#   '1920s',
#   'new',
#   'york',
#   'portrayed',
#   'while',
#   'his',
#   'son',
#   ',',
#   'michael',
#   ',',
#   'expands',
#   'and',
#   'tightens',
#   'his',
#   'grip',
#   'the',
#   'family',
#   'crime',
#   'syndicate',
#   '.'],
#  ['when',
#   'the',
#   'menace',
#   'known',
#   'the',
#   'joker',
#   'emerges',
#   'from',
#   'his',
#   'mysterious',
#   'past',
#   ',',
#   'wreaks',
#   'havoc',
#   'and',
#   'chaos',
#   'the',
#   'people',
#   'gotham',
#   ',',
#   'the',
#   'dark',
#   'knight',
#   'must',
#   'accept',
#   'one',
#   'the',
#   'greatest',
#   'psychological',
#   'and',
#   'physical',
#   'tests',
#   'his',
#   'ability',
#   'fight',
#   'injustice',
#   '.'],
#  ['jury',
#   'holdout',
#   'attempts',
#   'prevent',
#   'miscarriage',
#   'justice',
#   'forcing',
#   'his',
#   'colleagues',
#   'reconsider',
#   'the',
#   'evidence',
#   '.'],
#  ['german-occupied',
#   'poland',
#   'during',
#   'world',
#   'war',
#   'ii',
#   ',',
#   'oskar',
#   'schindler',
#   'gradually',
#   'becomes',
#   'concerned',
#   'for',
#   'his',
#   'jewish',
#   'workforce',
#   'after',
#   'witnessing',
#   'their',
#   'persecution',
#   'the',
#   'nazi',
#   'germans',
#   '.'],
#  ['gandalf',
#   'and',
#   'aragorn',
#   'lead',
#   'the',
#   'world',
#   'men',
#   'against',
#   'sauron',
#   "'s",
#   'army',
#   'draw',
#   'his',
#   'gaze',
#   'from',
#   'frodo',
#   'and',
#   'sam',
#   'they',
#   'approach',
#   'mount',
#   'doom',
#   'with',
#   'the',
#   'one',
#   'ring',
#   '.'],
#  ['the',
#   'lives',
#   'two',
#   'mob',
#   'hit',
#   'men',
#   ',',
#   'boxer',
#   ',',
#   'gangster',
#   "'s",
#   'wife',
#   ',',
#   'and',
#   'pair',
#   'diner',
#   'bandits',
#   'intertwine',
#   'four',
#   'tales',
#   'violence',
#   'and',
#   'redemption',
#   '.'],
#  ['insomniac',
#   'office',
#   'worker',
#   ',',
#   'looking',
#   'for',
#   'way',
#   'change',
#   'his',
#   'life',
#   ',',
#   'crosses',
#   'paths',
#   'with',
#   'devil-may-care',
#   'soap',
#   'maker',
#   ',',
#   'forming',
#   'underground',
#   'fight',
#   'club',
#   'that',
#   'evolves',
#   'into',
#   'something',
#   'much',
#   ',',
#   'much',
#   'more',
#   '.'],
#  ['meek',
#   'hobbit',
#   'from',
#   'the',
#   'shire',
#   'and',
#   'eight',
#   'companions',
#   'set',
#   'out',
#   'journey',
#   'destroy',
#   'the',
#   'powerful',
#   'one',
#   'ring',
#   'and',
#   'save',
#   'middle',
#   'earth',
#   'from',
#   'the',
#   'dark',
#   'lord',
#   'sauron',
#   '.'],
#  ['while',
#   'not',
#   'intelligent',
#   ',',
#   'forrest',
#   'gump',
#   'has',
#   'accidentally',
#   'been',
#   'present',
#   'many',
#   'historic',
#   'moments',
#   ',',
#   'but',
#   'his',
#   'true',
#   'love',
#   ',',
#   'jenny',
#   'curran',
#   ',',
#   'eludes',
#   'him',
#   '.'],
#  ['after',
#   'the',
#   'rebels',
#   'are',
#   'overpowered',
#   'the',
#   'empire',
#   'their',
#   'newly',
#   'established',
#   'base',
#   ',',
#   'luke',
#   'skywalker',
#   'begins',
#   'jedi',
#   'training',
#   'with',
#   'master',
#   'yoda',
#   '.',
#   'his',
#   'friends',
#   'accept',
#   'shelter',
#   'from',
#   'questionable',
#   'ally',
#   'darth',
#   'vader',
#   'hunts',
#   'them',
#   'plan',
#   'capture',
#   'luke',
#   '.'],
#  ['thief',
#   ',',
#   'who',
#   'steals',
#   'corporate',
#   'secrets',
#   'through',
#   'use',
#   'dream-sharing',
#   'technology',
#   ',',
#   'given',
#   'the',
#   'inverse',
#   'task',
#   'planting',
#   'idea',
#   'into',
#   'the',
#   'mind',
#   'ceo',
#   '.'],
#  ['while',
#   'frodo',
#   'and',
#   'sam',
#   'edge',
#   'closer',
#   'mordor',
#   'with',
#   'the',
#   'help',
#   'the',
#   'shifty',
#   'gollum',
#   ',',
#   'the',
#   'divided',
#   'fellowship',
#   'makes',
#   'stand',
#   'against',
#   'sauron',
#   "'s",
#   'new',
#   'ally',
#   ',',
#   'saruman',
#   ',',
#   'and',
#   'his',
#   'hordes',
#   'isengard',
#   '.'],
#  ['criminal',
#   'pleads',
#   'insanity',
#   'after',
#   'getting',
#   'into',
#   'trouble',
#   'again',
#   'and',
#   'once',
#   'the',
#   'mental',
#   'institution',
#   'rebels',
#   'against',
#   'the',
#   'oppressive',
#   'nurse',
#   'and',
#   'rallies',
#   'the',
#   'scared',
#   'patients',
#   '.'],
#  ['the',
#   'story',
#   'henry',
#   'hill',
#   'and',
#   'his',
#   'life',
#   'through',
#   'the',
#   'teen',
#   'years',
#   'into',
#   'the',
#   'years',
#   'mafia',
#   ',',
#   'covering',
#   'his',
#   'relationship',
#   'with',
#   'wife',
#   'karen',
#   'hill',
#   'and',
#   'his',
#   'mob',
#   'partners',
#   'jimmy',
#   'conway',
#   'and',
#   'tommy',
#   'devitto',
#   'the',
#   'italian-american',
#   'crime',
#   'syndicate',
#   '.'],
#  ['computer',
#   'hacker',
#   'learns',
#   'from',
#   'mysterious',
#   'rebels',
#   'about',
#   'the',
#   'true',
#   'nature',
#   'his',
#   'reality',
#   'and',
#   'his',
#   'role',
#   'the',
#   'war',
#   'against',
#   'its',
#   'controllers',
#   '.'],
#  ['luke',
#   'skywalker',
#   'joins',
#   'forces',
#   'with',
#   'jedi',
#   'knight',
#   ',',
#   'cocky',
#   'pilot',
#   ',',
#   'wookiee',
#   'and',
#   'two',
#   'droids',
#   'save',
#   'the',
#   'galaxy',
#   'from',
#   'the',
#   'empire',
#   "'s",
#   'world-destroying',
#   'battle-station',
#   ',',
#   'while',
#   'also',
#   'attempting',
#   'rescue',
#   'princess',
#   'leia',
#   'from',
#   'the',
#   'evil',
#   'darth',
#   'vader',
#   '.'],
#  ['two',
#   'detectives',
#   ',',
#   'rookie',
#   'and',
#   'veteran',
#   ',',
#   'hunt',
#   'serial',
#   'killer',
#   'who',
#   'uses',
#   'the',
#   'seven',
#   'deadly',
#   'sins',
#   'his',
#   'motives',
#   '.'],
#  ['angel',
#   'sent',
#   'from',
#   'heaven',
#   'help',
#   'desperately',
#   'frustrated',
#   'businessman',
#   'showing',
#   'him',
#   'what',
#   'life',
#   'would',
#   'have',
#   'been',
#   'like',
#   'had',
#   'never',
#   'existed',
#   '.'],
#  ['young',
#   'f.b.i',
#   '.',
#   'cadet',
#   'must',
#   'confide',
#   'incarcerated',
#   'and',
#   'manipulative',
#   'killer',
#   'receive',
#   'his',
#   'help',
#   'catching',
#   'another',
#   'serial',
#   'killer',
#   'who',
#   'skins',
#   'his',
#   'victims',
#   '.'],
#  ['sole',
#   'survivor',
#   'tells',
#   'the',
#   'twisty',
#   'events',
#   'leading',
#   'horrific',
#   'gun',
#   'battle',
#   'boat',
#   ',',
#   'which',
#   'began',
#   'when',
#   'five',
#   'criminals',
#   'met',
#   'seemingly',
#   'random',
#   'police',
#   'lineup',
#   '.'],
#  ['mathilda',
#   ',',
#   '12-year-old',
#   'girl',
#   ',',
#   'reluctantly',
#   'taken',
#   'léon',
#   ',',
#   'professional',
#   'assassin',
#   ',',
#   'after',
#   'her',
#   'family',
#   'murdered',
#   '.',
#   'léon',
#   'and',
#   'mathilda',
#   'form',
#   'unusual',
#   'relationship',
#   ',',
#   'she',
#   'becomes',
#   'his',
#   'protégée',
#   'and',
#   'learns',
#   'the',
#   'assassin',
#   "'s",
#   'trade',
#   '.'],
#  ['following',
#   'the',
#   'normandy',
#   'landings',
#   ',',
#   'group',
#   'u.s.',
#   'soldiers',
#   'go',
#   'behind',
#   'enemy',
#   'lines',
#   'retrieve',
#   'paratrooper',
#   'whose',
#   'brothers',
#   'have',
#   'been',
#   'killed',
#   'action',
#   '.'],
#  ['with',
#   'the',
#   'aid',
#   'wealthy',
#   'erratic',
#   'tippler',
#   ',',
#   'dewy-eyed',
#   'tramp',
#   'who',
#   'has',
#   'fallen',
#   'love',
#   'with',
#   'sightless',
#   'flower',
#   'girl',
#   'accumulates',
#   'money',
#   'able',
#   'help',
#   'her',
#   'medically',
#   '.'],
#  ['team',
#   'explorers',
#   'travel',
#   'through',
#   'wormhole',
#   'space',
#   'attempt',
#   'ensure',
#   'humanity',
#   "'s",
#   'survival',
#   '.'],
#  ['former',
#   'neo-nazi',
#   'skinhead',
#   'tries',
#   'prevent',
#   'his',
#   'younger',
#   'brother',
#   'from',
#   'going',
#   'down',
#   'the',
#   'same',
#   'wrong',
#   'path',
#   'that',
#   'did',
#   '.'],
#  ['the',
#   'tramp',
#   'struggles',
#   'live',
#   'modern',
#   'industrial',
#   'society',
#   'with',
#   'the',
#   'help',
#   'young',
#   'homeless',
#   'woman',
#   '.'],
#  ['casablanca',
#   'december',
#   '1941',
#   ',',
#   'cynical',
#   'american',
#   'expatriate',
#   'encounters',
#   'former',
#   'lover',
#   ',',
#   'with',
#   'unforeseen',
#   'complications',
#   '.'],
#  ['the',
#   'lives',
#   'guards',
#   'death',
#   'row',
#   'are',
#   'affected',
#   'one',
#   'their',
#   'charges',
#   ':',
#   'black',
#   'man',
#   'accused',
#   'child',
#   'murder',
#   'and',
#   'rape',
#   ',',
#   'yet',
#   'who',
#   'has',
#   'mysterious',
#   'gift',
#   '.'],
#  ['phoenix',
#   'secretary',
#   'embezzles',
#   '$',
#   '40,000',
#   'from',
#   'her',
#   'employer',
#   "'s",
#   'client',
#   ',',
#   'goes',
#   'the',
#   'run',
#   ',',
#   'and',
#   'checks',
#   'into',
#   'remote',
#   'motel',
#   'run',
#   'young',
#   'man',
#   'under',
#   'the',
#   'domination',
#   'his',
#   'mother',
#   '.'],
#  ['archaeologist',
#   'and',
#   'adventurer',
#   'indiana',
#   'jones',
#   'hired',
#   'the',
#   'u.s.',
#   'government',
#   'find',
#   'the',
#   'ark',
#   'the',
#   'covenant',
#   'before',
#   'the',
#   'nazis',
#   '.'],
#  ['polish',
#   'jewish',
#   'musician',
#   'struggles',
#   'survive',
#   'the',
#   'destruction',
#   'the',
#   'warsaw',
#   'ghetto',
#   'world',
#   'war',
#   'ii',
#   '.'],
#  ['wheelchair-bound',
#   'photographer',
#   'spies',
#   'his',
#   'neighbours',
#   'from',
#   'his',
#   'apartment',
#   'window',
#   'and',
#   'becomes',
#   'convinced',
#   'one',
#   'them',
#   'has',
#   'committed',
#   'murder',
#   '.'],
#  ['undercover',
#   'cop',
#   'and',
#   'mole',
#   'the',
#   'police',
#   'attempt',
#   'identify',
#   'each',
#   'other',
#   'while',
#   'infiltrating',
#   'irish',
#   'gang',
#   'south',
#   'boston',
#   '.'],
#  ['promising',
#   'young',
#   'drummer',
#   'enrolls',
#   'cut-throat',
#   'music',
#   'conservatory',
#   'where',
#   'his',
#   'dreams',
#   'greatness',
#   'are',
#   'mentored',
#   'instructor',
#   'who',
#   'will',
#   'stop',
#   'nothing',
#   'realize',
#   'student',
#   "'s",
#   'potential',
#   '.'],
#  ['cyborg',
#   ',',
#   'identical',
#   'the',
#   'one',
#   'who',
#   'failed',
#   'kill',
#   'sarah',
#   'connor',
#   ',',
#   'must',
#   'now',
#   'protect',
#   'her',
#   'ten',
#   'year',
#   'old',
#   'son',
#   ',',
#   'john',
#   'connor',
#   ',',
#   'from',
#   'more',
#   'advanced',
#   'cyborg',
#   '.'],
#  ['marty',
#   'mcfly',
#   ',',
#   '17-year-old',
#   'high',
#   'school',
#   'student',
#   ',',
#   'accidentally',
#   'sent',
#   '30',
#   'years',
#   'into',
#   'the',
#   'past',
#   'time-traveling',
#   'delorean',
#   'invented',
#   'his',
#   'close',
#   'friend',
#   ',',
#   'the',
#   'maverick',
#   'scientist',
#   'doc',
#   'brown',
#   '.'],
#  ['when',
#   'roman',
#   'general',
#   'betrayed',
#   'and',
#   'his',
#   'family',
#   'murdered',
#   'emperor',
#   "'s",
#   'corrupt',
#   'son',
#   ',',
#   'comes',
#   'rome',
#   'gladiator',
#   'seek',
#   'revenge',
#   '.'],
#  ['lion',
#   'cub',
#   'and',
#   'future',
#   'king',
#   'simba',
#   'searches',
#   'for',
#   'his',
#   'identity',
#   '.',
#   'his',
#   'eagerness',
#   'please',
#   'others',
#   'and',
#   'penchant',
#   'for',
#   'testing',
#   'his',
#   'boundaries',
#   'sometimes',
#   'gets',
#   'him',
#   'into',
#   'trouble',
#   '.'],
#  ['two',
#   'stage',
#   'magicians',
#   'engage',
#   'competitive',
#   'one-upmanship',
#   'attempt',
#   'create',
#   'the',
#   'ultimate',
#   'stage',
#   'illusion',
#   '.'],
#  ['during',
#   'the',
#   'vietnam',
#   'war',
#   ',',
#   'captain',
#   'willard',
#   'sent',
#   'dangerous',
#   'mission',
#   'into',
#   'cambodia',
#   'assassinate',
#   'renegade',
#   'colonel',
#   'who',
#   'has',
#   'set',
#   'himself',
#   'god',
#   'among',
#   'local',
#   'tribe',
#   '.'],
#  ['man',
#   'juggles',
#   'searching',
#   'for',
#   'his',
#   'wife',
#   "'s",
#   'murderer',
#   'and',
#   'keeping',
#   'his',
#   'short-term',
#   'memory',
#   'loss',
#   'from',
#   'being',
#   'obstacle',
#   '.'],
#  ['dictator',
#   'adenoid',
#   'hynkel',
#   'tries',
#   'expand',
#   'his',
#   'empire',
#   'while',
#   'poor',
#   'jewish',
#   'barber',
#   'tries',
#   'avoid',
#   'persecution',
#   'from',
#   'hynkel',
#   "'s",
#   'regime',
#   '.'],
#  ['screenwriter',
#   'hired',
#   'rework',
#   'faded',
#   'silent',
#   'film',
#   'star',
#   "'s",
#   'script',
#   'only',
#   'find',
#   'himself',
#   'developing',
#   'dangerous',
#   'relationship',
#   '.'],
#  ['after',
#   'space',
#   'merchant',
#   'vessel',
#   'perceives',
#   'unknown',
#   'transmission',
#   'distress',
#   'call',
#   ',',
#   'its',
#   'landing',
#   'the',
#   'source',
#   'moon',
#   'finds',
#   'one',
#   'the',
#   'crew',
#   'attacked',
#   'mysterious',
#   'life-form',
#   ',',
#   'and',
#   'they',
#   'soon',
#   'realize',
#   'that',
#   'its',
#   'life',
#   'cycle',
#   'has',
#   'merely',
#   'begun',
#   '.'],
#  ['insane',
#   'general',
#   'triggers',
#   'path',
#   'nuclear',
#   'holocaust',
#   'that',
#   'war',
#   'room',
#   'full',
#   'politicians',
#   'and',
#   'generals',
#   'frantically',
#   'try',
#   'stop',
#   '.'],
#  ['after',
#   'refusing',
#   'attack',
#   'enemy',
#   'position',
#   ',',
#   'general',
#   'accuses',
#   'the',
#   'soldiers',
#   'cowardice',
#   'and',
#   'their',
#   'commanding',
#   'officer',
#   'must',
#   'defend',
#   'them',
#   '.'],
#  ['with',
#   'the',
#   'help',
#   'german',
#   'bounty',
#   'hunter',
#   ',',
#   'freed',
#   'slave',
#   'sets',
#   'out',
#   'rescue',
#   'his',
#   'wife',
#   'from',
#   'brutal',
#   'mississippi',
#   'plantation',
#   'owner',
#   '.'],
#  ['family',
#   'heads',
#   'isolated',
#   'hotel',
#   'for',
#   'the',
#   'winter',
#   'where',
#   'evil',
#   'and',
#   'spiritual',
#   'presence',
#   'influences',
#   'the',
#   'father',
#   'into',
#   'violence',
#   ',',
#   'while',
#   'his',
#   'psychic',
#   'son',
#   'sees',
#   'horrific',
#   'forebodings',
#   'from',
#   'the',
#   'past',
#   'and',
#   'the',
#   'future',
#   '.'],
#  ['veteran',
#   'british',
#   'barrister',
#   'must',
#   'defend',
#   'his',
#   'client',
#   'murder',
#   'trial',
#   'that',
#   'has',
#   'surprise',
#   'after',
#   'surprise',
#   '.'],
#  ['eight',
#   'years',
#   'after',
#   'the',
#   'joker',
#   "'s",
#   'reign',
#   'anarchy',
#   ',',
#   'the',
#   'dark',
#   'knight',
#   ',',
#   'with',
#   'the',
#   'help',
#   'the',
#   'enigmatic',
#   'selina',
#   ',',
#   'forced',
#   'from',
#   'his',
#   'imposed',
#   'exile',
#   'save',
#   'gotham',
#   'city',
#   ',',
#   'now',
#   'the',
#   'edge',
#   'total',
#   'annihilation',
#   ',',
#   'from',
#   'the',
#   'brutal',
#   'guerrilla',
#   'terrorist',
#   'bane',
#   '.'],
#  ['the',
#   'distant',
#   'future',
#   ',',
#   'small',
#   'waste-collecting',
#   'robot',
#   'inadvertently',
#   'embarks',
#   'space',
#   'journey',
#   'that',
#   'will',
#   'ultimately',
#   'decide',
#   'the',
#   'fate',
#   'mankind',
#   '.'],
#  ['sexually',
#   'frustrated',
#   'suburban',
#   'father',
#   'has',
#   'mid-life',
#   'crisis',
#   'after',
#   'becoming',
#   'infatuated',
#   'with',
#   'his',
#   'daughter',
#   "'s",
#   'best',
#   'friend',
#   '.'],
#  ['former',
#   'prohibition-era',
#   'jewish',
#   'gangster',
#   'returns',
#   'the',
#   'lower',
#   'east',
#   'side',
#   'manhattan',
#   'over',
#   'thirty',
#   'years',
#   'later',
#   ',',
#   'where',
#   'once',
#   'again',
#   'must',
#   'confront',
#   'the',
#   'ghosts',
#   'and',
#   'regrets',
#   'his',
#   'old',
#   'life',
#   '.'],
#  ['the',
#   'moon',
#   'from',
#   'alien',
#   '(',
#   '1979',
#   ')',
#   'has',
#   'been',
#   'colonized',
#   ',',
#   'but',
#   'contact',
#   'lost',
#   '.',
#   'this',
#   'time',
#   ',',
#   'the',
#   'rescue',
#   'team',
#   'has',
#   'impressive',
#   'firepower',
#   ',',
#   'but',
#   'will',
#   'enough',
#   '?'],
#  ['following',
#   'the',
#   'death',
#   'publishing',
#   'tycoon',
#   ',',
#   'news',
#   'reporters',
#   'scramble',
#   'discover',
#   'the',
#   'meaning',
#   'his',
#   'final',
#   'utterance',
#   '.'],
#  ['hapless',
#   'new',
#   'york',
#   'advertising',
#   'executive',
#   'mistaken',
#   'for',
#   'government',
#   'agent',
#   'group',
#   'foreign',
#   'spies',
#   ',',
#   'and',
#   'pursued',
#   'across',
#   'the',
#   'country',
#   'while',
#   'looks',
#   'for',
#   'way',
#   'survive',
#   '.'],
#  ['san',
#   'francisco',
#   'detective',
#   'suffering',
#   'from',
#   'acrophobia',
#   'investigates',
#   'the',
#   'strange',
#   'activities',
#   'old',
#   'friend',
#   "'s",
#   'wife',
#   ',',
#   'all',
#   'the',
#   'while',
#   'becoming',
#   'dangerously',
#   'obsessed',
#   'with',
#   'her',
#   '.'],
#  ['after',
#   'daring',
#   'mission',
#   'rescue',
#   'han',
#   'solo',
#   'from',
#   'jabba',
#   'the',
#   'hutt',
#   ',',
#   'the',
#   'rebels',
#   'dispatch',
#   'endor',
#   'destroy',
#   'more',
#   'powerful',
#   'death',
#   'star',
#   '.',
#   'meanwhile',
#   ',',
#   'luke',
#   'struggles',
#   'help',
#   'vader',
#   'back',
#   'from',
#   'the',
#   'dark',
#   'side',
#   'without',
#   'falling',
#   'into',
#   'the',
#   'emperor',
#   "'s",
#   'trap',
#   '.'],
#  ['when',
#   'his',
#   'secret',
#   'bride',
#   'executed',
#   'for',
#   'assaulting',
#   'english',
#   'soldier',
#   'who',
#   'tried',
#   'rape',
#   'her',
#   ',',
#   'sir',
#   'william',
#   'wallace',
#   'begins',
#   'revolt',
#   'against',
#   'king',
#   'edward',
#   'england',
#   '.'],
#  ['after',
#   'simple',
#   'jewelry',
#   'heist',
#   'goes',
#   'terribly',
#   'wrong',
#   ',',
#   'the',
#   'surviving',
#   'criminals',
#   'begin',
#   'suspect',
#   'that',
#   'one',
#   'them',
#   'police',
#   'informant',
#   '.'],
#  ['insurance',
#   'representative',
#   'lets',
#   'himself',
#   'talked',
#   'into',
#   'murder/insurance',
#   'fraud',
#   'scheme',
#   'that',
#   'arouses',
#   'insurance',
#   'investigator',
#   "'s",
#   'suspicions',
#   '.'],
#  ['the',
#   'drug-induced',
#   'utopias',
#   'four',
#   'coney',
#   'island',
#   'people',
#   'are',
#   'shattered',
#   'when',
#   'their',
#   'addictions',
#   'run',
#   'deep',
#   '.'],
#  ['the',
#   'story',
#   't.e',
#   '.',
#   'lawrence',
#   ',',
#   'the',
#   'english',
#   'officer',
#   'who',
#   'successfully',
#   'united',
#   'and',
#   'led',
#   'the',
#   'diverse',
#   ',',
#   'often',
#   'warring',
#   ',',
#   'arab',
#   'tribes',
#   'during',
#   'world',
#   'war',
#   'order',
#   'fight',
#   'the',
#   'turks',
#   '.'],
#  ['the',
#   'tramp',
#   'cares',
#   'for',
#   'abandoned',
#   'child',
#   ',',
#   'but',
#   'events',
#   'put',
#   'that',
#   'relationship',
#   'jeopardy',
#   '.'],
#  ['future',
#   'britain',
#   ',',
#   'alex',
#   'delarge',
#   ',',
#   'charismatic',
#   'and',
#   'psycopath',
#   'delinquent',
#   ',',
#   'who',
#   'likes',
#   'practice',
#   'crimes',
#   'and',
#   'ultra-violence',
#   'with',
#   'his',
#   'gang',
#   ',',
#   'jailed',
#   'and',
#   'volunteers',
#   'for',
#   'experimental',
#   'aversion',
#   'therapy',
#   'developed',
#   'the',
#   'government',
#   'effort',
#   'solve',
#   'society',
#   "'s",
#   'crime',
#   'problem',
#   '-',
#   'but',
#   'not',
#   'all',
#   'goes',
#   'according',
#   'plan',
#   '.'],
#  ['the',
#   'incredible',
#   'story',
#   'wolfgang',
#   'amadeus',
#   'mozart',
#   ',',
#   'told',
#   'his',
#   'peer',
#   'and',
#   'secret',
#   'rival',
#   'antonio',
#   'salieri',
#   '-',
#   'now',
#   'confined',
#   'insane',
#   'asylum',
#   '.'],
#  ['atticus',
#   'finch',
#   ',',
#   'lawyer',
#   'the',
#   'depression-era',
#   'south',
#   ',',
#   'defends',
#   'black',
#   'man',
#   'against',
#   'undeserved',
#   'rape',
#   'charge',
#   ',',
#   'and',
#   'his',
#   'children',
#   'against',
#   'prejudice',
#   '.'],
#  ['when',
#   'their',
#   'relationship',
#   'turns',
#   'sour',
#   ',',
#   'couple',
#   'undergoes',
#   'procedure',
#   'have',
#   'each',
#   'other',
#   'erased',
#   'from',
#   'their',
#   'memories',
#   '.',
#   'but',
#   'only',
#   'through',
#   'the',
#   'process',
#   'loss',
#   'that',
#   'they',
#   'discover',
#   'what',
#   'they',
#   'had',
#   'begin',
#   'with',
#   '.'],
#  ['silent',
#   'film',
#   'production',
#   'company',
#   'and',
#   'cast',
#   'make',
#   'difficult',
#   'transition',
#   'sound',
#   '.'],
#  ['mentally',
#   'unstable',
#   'vietnam',
#   'war',
#   'veteran',
#   'works',
#   'night-time',
#   'taxi',
#   'driver',
#   'new',
#   'york',
#   'city',
#   'where',
#   'the',
#   'perceived',
#   'decadence',
#   'and',
#   'sleaze',
#   'feeds',
#   'his',
#   'urge',
#   'for',
#   'violent',
#   'action',
#   ',',
#   'while',
#   'attempting',
#   'save',
#   'preadolescent',
#   'prostitute',
#   'the',
#   'process',
#   '.'],
#  ['chicago',
#   'september',
#   '1936',
#   ',',
#   'young',
#   'con',
#   'man',
#   'seeking',
#   'revenge',
#   'for',
#   'his',
#   'murdered',
#   'partner',
#   'teams',
#   'with',
#   'master',
#   'the',
#   'big',
#   'con',
#   'win',
#   'fortune',
#   'from',
#   'criminal',
#   'banker',
#   '.'],
#  ['the',
#   'toys',
#   'are',
#   'mistakenly',
#   'delivered',
#   'day-care',
#   'center',
#   'instead',
#   'the',
#   'attic',
#   'right',
#   'before',
#   'andy',
#   'leaves',
#   'for',
#   'college',
#   ',',
#   'and',
#   "'s",
#   'woody',
#   'convince',
#   'the',
#   'other',
#   'toys',
#   'that',
#   'they',
#   'were',
#   "n't",
#   'abandoned',
#   'and',
#   'return',
#   'home',
#   '.'],
#  ['humanity',
#   'finds',
#   'mysterious',
#   ',',
#   'obviously',
#   'artificial',
#   'object',
#   'buried',
#   'beneath',
#   'the',
#   'lunar',
#   'surface',
#   'and',
#   ',',
#   'with',
#   'the',
#   'intelligent',
#   'computer',
#   'h.a.l',
#   '.',
#   '9000',
#   ',',
#   'sets',
#   'off',
#   'quest',
#   '.'],
#  ['pragmatic',
#   'u.s.',
#   'marine',
#   'observes',
#   'the',
#   'dehumanizing',
#   'effects',
#   'the',
#   'vietnam',
#   'war',
#   'has',
#   'his',
#   'fellow',
#   'recruits',
#   'from',
#   'their',
#   'brutal',
#   'boot',
#   'camp',
#   'training',
#   'the',
#   'bloody',
#   'street',
#   'fighting',
#   'hue',
#   '.'],
#  ['after',
#   'being',
#   'coerced',
#   'into',
#   'working',
#   'for',
#   'crime',
#   'boss',
#   ',',
#   'young',
#   'getaway',
#   'driver',
#   'finds',
#   'himself',
#   'taking',
#   'part',
#   'heist',
#   'doomed',
#   'fail',
#   '.'],
#  ['cowboy',
#   'doll',
#   'profoundly',
#   'threatened',
#   'and',
#   'jealous',
#   'when',
#   'new',
#   'spaceman',
#   'figure',
#   'supplants',
#   'him',
#   'top',
#   'toy',
#   'boy',
#   "'s",
#   'room',
#   '.'],
#  ['nazi-occupied',
#   'france',
#   'during',
#   'world',
#   'war',
#   'ii',
#   ',',
#   'plan',
#   'assassinate',
#   'nazi',
#   'leaders',
#   'group',
#   'jewish',
#   'u.s.',
#   'soldiers',
#   'coincides',
#   'with',
#   'theatre',
#   'owner',
#   "'s",
#   'vengeful',
#   'plans',
#   'for',
#   'the',
#   'same',
#   '.'],
#  ['unscrupulous',
#   'boxing',
#   'promoters',
#   ',',
#   'violent',
#   'bookmakers',
#   ',',
#   'russian',
#   'gangster',
#   ',',
#   'incompetent',
#   'amateur',
#   'robbers',
#   ',',
#   'and',
#   'supposedly',
#   'jewish',
#   'jewelers',
#   'fight',
#   'track',
#   'down',
#   'priceless',
#   'stolen',
#   'diamond',
#   '.'],
#  ['man',
#   'tries',
#   'rise',
#   'his',
#   'company',
#   'letting',
#   'its',
#   'executives',
#   'use',
#   'his',
#   'apartment',
#   'for',
#   'trysts',
#   ',',
#   'but',
#   'complications',
#   'and',
#   'romance',
#   'his',
#   'own',
#   'ensue',
#   '.'],
#  ['ingenue',
#   'insinuates',
#   'herself',
#   'into',
#   'the',
#   'company',
#   'established',
#   'but',
#   'aging',
#   'stage',
#   'actress',
#   'and',
#   'her',
#   'circle',
#   'theater',
#   'friends',
#   '.'],
#  ['king',
#   'arthur',
#   'and',
#   'his',
#   'knights',
#   'embark',
#   'low-budget',
#   'search',
#   'for',
#   'the',
#   'grail',
#   ',',
#   'encountering',
#   'many',
#   ',',
#   'very',
#   'silly',
#   'obstacles',
#   '.'],
#  ['miami',
#   '1980',
#   ',',
#   'determined',
#   'cuban',
#   'immigrant',
#   'takes',
#   'over',
#   'drug',
#   'cartel',
#   'and',
#   'succumbs',
#   'greed',
#   '.'],
#  ['corruption',
#   'grows',
#   '1950s',
#   'la',
#   ',',
#   'three',
#   'policemen',
#   '-',
#   'one',
#   'strait-laced',
#   ',',
#   'one',
#   'brutal',
#   ',',
#   'and',
#   'one',
#   'sleazy',
#   '-',
#   'investigate',
#   'series',
#   'murders',
#   'with',
#   'their',
#   'own',
#   'brand',
#   'justice',
#   '.'],
#  ['will',
#   'hunting',
#   ',',
#   'janitor',
#   'm.i.t.',
#   ',',
#   'has',
#   'gift',
#   'for',
#   'mathematics',
#   ',',
#   'but',
#   'needs',
#   'help',
#   'from',
#   'psychologist',
#   'find',
#   'direction',
#   'his',
#   'life',
#   '.'],
#  ['fred',
#   'dobbs',
#   'and',
#   'bob',
#   'curtin',
#   ',',
#   'two',
#   'americans',
#   'searching',
#   'for',
#   'work',
#   'mexico',
#   ',',
#   'convince',
#   'old',
#   'prospector',
#   'help',
#   'them',
#   'mine',
#   'for',
#   'gold',
#   'the',
#   'sierra',
#   'madre',
#   'mountains',
#   '.'],
#  ['when',
#   'dr.',
#   'henry',
#   'jones',
#   'sr.',
#   'suddenly',
#   'goes',
#   'missing',
#   'while',
#   'pursuing',
#   'the',
#   'holy',
#   'grail',
#   ',',
#   'eminent',
#   'archaeologist',
#   'indiana',
#   'jones',
#   'must',
#   'follow',
#   'his',
#   'father',
#   "'s",
#   'footsteps',
#   'stop',
#   'the',
#   'nazis',
#   'from',
#   'getting',
#   'their',
#   'hands',
#   'the',
#   'holy',
#   'grail',
#   'first',
#   '.'],
#  ['when',
#   'two',
#   'male',
#   'musicians',
#   'witness',
#   'mob',
#   'hit',
#   ',',
#   'they',
#   'flee',
#   'the',
#   'state',
#   'all-female',
#   'band',
#   'disguised',
#   'women',
#   ',',
#   'but',
#   'further',
#   'complications',
#   'set',
#   '.'],
#  ['after',
#   'training',
#   'with',
#   'his',
#   'mentor',
#   ',',
#   'batman',
#   'begins',
#   'his',
#   'fight',
#   'free',
#   'crime-ridden',
#   'gotham',
#   'city',
#   'from',
#   'the',
#   'corruption',
#   'that',
#   'scarecrow',
#   'and',
#   'the',
#   'league',
#   'shadows',
#   'have',
#   'cast',
#   'upon',
#   '.'],
#  ['seventy-eight',
#   'year',
#   'old',
#   'carl',
#   'fredricksen',
#   'travels',
#   'paradise',
#   'falls',
#   'his',
#   'home',
#   'equipped',
#   'with',
#   'balloons',
#   ',',
#   'inadvertently',
#   'taking',
#   'young',
#   'stowaway',
#   '.'],
#  ['pulp',
#   'novelist',
#   'holly',
#   'martins',
#   'travels',
#   'shadowy',
#   ',',
#   'postwar',
#   'vienna',
#   ',',
#   'only',
#   'find',
#   'himself',
#   'investigating',
#   'the',
#   'mysterious',
#   'death',
#   'old',
#   'friend',
#   ',',
#   'harry',
#   'lime',
#   '.'],
#  ['retired',
#   'old',
#   'west',
#   'gunslinger',
#   'william',
#   'munny',
#   'reluctantly',
#   'takes',
#   'one',
#   'last',
#   'job',
#   ',',
#   'with',
#   'the',
#   'help',
#   'his',
#   'old',
#   'partner',
#   'and',
#   'young',
#   'man',
#   '.'],
#  ['1948',
#   ',',
#   'american',
#   'court',
#   'occupied',
#   'germany',
#   'tries',
#   'four',
#   'nazi',
#   'judges',
#   'for',
#   'war',
#   'crimes',
#   '.'],
#  ['emotionally',
#   'self-destructive',
#   'boxer',
#   "'s",
#   'journey',
#   'through',
#   'life',
#   ',',
#   'the',
#   'violence',
#   'and',
#   'temper',
#   'that',
#   'leads',
#   'him',
#   'the',
#   'top',
#   'the',
#   'ring',
#   'destroys',
#   'his',
#   'life',
#   'outside',
#   '.'],
#  ['allied',
#   'prisoners',
#   'war',
#   'plan',
#   'for',
#   'several',
#   'hundred',
#   'their',
#   'number',
#   'escape',
#   'from',
#   'german',
#   'camp',
#   'during',
#   'world',
#   'war',
#   'ii',
#   '.'],
#  ['group',
#   'professional',
#   'bank',
#   'robbers',
#   'start',
#   'feel',
#   'the',
#   'heat',
#   'from',
#   'police',
#   'when',
#   'they',
#   'unknowingly',
#   'leave',
#   'clue',
#   'their',
#   'latest',
#   'heist',
#   ',',
#   'while',
#   'both',
#   'sides',
#   'attempt',
#   'find',
#   'balance',
#   'between',
#   'their',
#   'personal',
#   'lives',
#   'with',
#   'their',
#   'professional',
#   'lives',
#   '.'],
#  ['john',
#   'mcclane',
#   ',',
#   'officer',
#   'the',
#   'nypd',
#   ',',
#   'tries',
#   'save',
#   'his',
#   'wife',
#   'holly',
#   'gennaro',
#   'and',
#   'several',
#   'others',
#   'that',
#   'were',
#   'taken',
#   'hostage',
#   'german',
#   'terrorist',
#   'hans',
#   'gruber',
#   'during',
#   'christmas',
#   'party',
#   'the',
#   'nakatomi',
#   'plaza',
#   'los',
#   'angeles',
#   '.'],
#  ['prospector',
#   'goes',
#   'the',
#   'klondike',
#   'search',
#   'gold',
#   'and',
#   'finds',
#   'and',
#   'more',
#   '.'],
#  ['private',
#   'detective',
#   'hired',
#   'expose',
#   'adulterer',
#   'finds',
#   'himself',
#   'caught',
#   'web',
#   'deceit',
#   ',',
#   'corruption',
#   ',',
#   'and',
#   'murder',
#   '.'],
#  ['ex-prize',
#   'fighter',
#   'turned',
#   'longshoreman',
#   'struggles',
#   'stand',
#   'his',
#   'corrupt',
#   'union',
#   'bosses',
#   '.'],
#  ['naive',
#   'man',
#   'appointed',
#   'fill',
#   'vacancy',
#   'the',
#   'united',
#   'states',
#   'senate',
#   '.',
#   'his',
#   'plans',
#   'promptly',
#   'collide',
#   'with',
#   'political',
#   'corruption',
#   ',',
#   'but',
#   'does',
#   "n't",
#   'back',
#   'down',
#   '.'],
#  ['when',
#   'union',
#   'spies',
#   'steal',
#   'engineer',
#   "'s",
#   'beloved',
#   'locomotive',
#   ',',
#   'pursues',
#   'single-handedly',
#   'and',
#   'straight',
#   'through',
#   'enemy',
#   'lines',
#   '.'],
#  ['after',
#   'young',
#   'riley',
#   'uprooted',
#   'from',
#   'her',
#   'midwest',
#   'life',
#   'and',
#   'moved',
#   'san',
#   'francisco',
#   ',',
#   'her',
#   'emotions',
#   '-',
#   'joy',
#   ',',
#   'fear',
#   ',',
#   'anger',
#   ',',
#   'disgust',
#   'and',
#   'sadness',
#   '-',
#   'conflict',
#   'how',
#   'best',
#   'navigate',
#   'new',
#   'city',
#   ',',
#   'house',
#   ',',
#   'and',
#   'school',
#   '.'],
#  ['after',
#   'settling',
#   'his',
#   'differences',
#   'with',
#   'japanese',
#   'pow',
#   'camp',
#   'commander',
#   ',',
#   'british',
#   'colonel',
#   'co-operates',
#   'oversee',
#   'his',
#   'men',
#   "'s",
#   'construction',
#   'railway',
#   'bridge',
#   'for',
#   'their',
#   'captors',
#   '-',
#   'while',
#   'oblivious',
#   'plan',
#   'the',
#   'allies',
#   'destroy',
#   '.'],
#  ['young', 'boy', 'raised', 'within', 'the', 'confines', 'small', 'shed', '.'],
#  ['jazz',
#   'pianist',
#   'falls',
#   'for',
#   'aspiring',
#   'actress',
#   'los',
#   'angeles',
#   '.'],
#  ['the',
#   'near',
#   'future',
#   ',',
#   'weary',
#   'logan',
#   'cares',
#   'for',
#   'ailing',
#   'professor',
#   'x',
#   'somewhere',
#   'the',
#   'mexican',
#   'border',
#   '.',
#   'however',
#   ',',
#   'logan',
#   "'s",
#   'attempts',
#   'hide',
#   'from',
#   'the',
#   'world',
#   'and',
#   'his',
#   'legacy',
#   'are',
#   'upended',
#   'when',
#   'young',
#   'mutant',
#   'arrives',
#   ',',
#   'pursued',
#   'dark',
#   'forces',
#   '.'],
#  ['blade',
#   'runner',
#   'must',
#   'pursue',
#   'and',
#   'try',
#   'terminate',
#   'four',
#   'replicants',
#   'who',
#   'stole',
#   'ship',
#   'space',
#   'and',
#   'have',
#   'returned',
#   'earth',
#   'find',
#   'their',
#   'creator',
#   '.'],
#  ['botched',
#   'card',
#   'game',
#   'london',
#   'triggers',
#   'four',
#   'friends',
#   ',',
#   'thugs',
#   ',',
#   'weed-growers',
#   ',',
#   'hard',
#   'gangsters',
#   ',',
#   'loan',
#   'sharks',
#   'and',
#   'debt',
#   'collectors',
#   'collide',
#   'with',
#   'each',
#   'other',
#   'series',
#   'unexpected',
#   'events',
#   ',',
#   'all',
#   'for',
#   'the',
#   'sake',
#   'weed',
#   ',',
#   'cash',
#   'and',
#   'two',
#   'antique',
#   'shotguns',
#   '.'],
#  ['greed',
#   ',',
#   'deception',
#   ',',
#   'money',
#   ',',
#   'power',
#   ',',
#   'and',
#   'murder',
#   'occur',
#   'between',
#   'two',
#   'best',
#   'friends',
#   ':',
#   'mafia',
#   'underboss',
#   'and',
#   'casino',
#   'owner',
#   ',',
#   'for',
#   'trophy',
#   'wife',
#   'over',
#   'gambling',
#   'empire',
#   '.'],
#  ['after',
#   'john',
#   'nash',
#   ',',
#   'brilliant',
#   'but',
#   'asocial',
#   'mathematician',
#   ',',
#   'accepts',
#   'secret',
#   'work',
#   'cryptography',
#   ',',
#   'his',
#   'life',
#   'takes',
#   'turn',
#   'for',
#   'the',
#   'nightmarish',
#   '.'],
#  ['victorian',
#   'surgeon',
#   'rescues',
#   'heavily',
#   'disfigured',
#   'man',
#   'who',
#   'mistreated',
#   'while',
#   'scraping',
#   'living',
#   'side-show',
#   'freak',
#   '.',
#   'behind',
#   'his',
#   'monstrous',
#   'facade',
#   ',',
#   'there',
#   'revealed',
#   'person',
#   'intelligence',
#   'and',
#   'sensitivity',
#   '.'],
#  ['the',
#   'youngest',
#   'son',
#   'alcoholic',
#   'former',
#   'boxer',
#   'returns',
#   'home',
#   ',',
#   'where',
#   "'s",
#   'trained',
#   'his',
#   'father',
#   'for',
#   'competition',
#   'mixed',
#   'martial',
#   'arts',
#   'tournament',
#   '-',
#   'path',
#   'that',
#   'puts',
#   'the',
#   'fighter',
#   'collision',
#   'course',
#   'with',
#   'his',
#   'estranged',
#   ',',
#   'older',
#   'brother',
#   '.'],
#  ['future',
#   'british',
#   'tyranny',
#   ',',
#   'shadowy',
#   'freedom',
#   'fighter',
#   ',',
#   'known',
#   'only',
#   'the',
#   'alias',
#   '``',
#   'v',
#   "''",
#   ',',
#   'plots',
#   'overthrow',
#   'with',
#   'the',
#   'help',
#   'young',
#   'woman',
#   '.'],
#  ['based',
#   'the',
#   'true',
#   'story',
#   'jordan',
#   'belfort',
#   ',',
#   'from',
#   'his',
#   'rise',
#   'wealthy',
#   'stock-broker',
#   'living',
#   'the',
#   'high',
#   'life',
#   'his',
#   'fall',
#   'involving',
#   'crime',
#   ',',
#   'corruption',
#   'and',
#   'the',
#   'federal',
#   'government',
#   '.'],
#  ['ex-tennis',
#   'pro',
#   'carries',
#   'out',
#   'plot',
#   'murder',
#   'his',
#   'wife',
#   '.',
#   'when',
#   'things',
#   'go',
#   'wrong',
#   ',',
#   'improvises',
#   'brilliant',
#   'plan',
#   'b',
#   '.'],
#  ['wwii',
#   'american',
#   'army',
#   'medic',
#   'desmond',
#   't.',
#   'doss',
#   ',',
#   'who',
#   'served',
#   'during',
#   'the',
#   'battle',
#   'okinawa',
#   ',',
#   'refuses',
#   'kill',
#   'people',
#   ',',
#   'and',
#   'becomes',
#   'the',
#   'first',
#   'man',
#   'american',
#   'history',
#   'receive',
#   'the',
#   'medal',
#   'honor',
#   'without',
#   'firing',
#   'shot',
#   '.'],
#  ['manipulative',
#   'woman',
#   'and',
#   'roguish',
#   'man',
#   'conduct',
#   'turbulent',
#   'romance',
#   'during',
#   'the',
#   'american',
#   'civil',
#   'war',
#   'and',
#   'reconstruction',
#   'periods',
#   '.'],
#  ['the',
#   '7th',
#   'century',
#   ',',
#   'mohammed',
#   ',',
#   'peace',
#   'upon',
#   'him',
#   ',',
#   'visited',
#   'angel',
#   'gabriel',
#   'who',
#   'urges',
#   'him',
#   'lead',
#   'the',
#   'people',
#   'mecca',
#   'and',
#   'worship',
#   'god',
#   '.',
#   'but',
#   'they',
#   "'re",
#   'exiled',
#   'medina',
#   'before',
#   'returning',
#   '...'],
#  ['self-conscious',
#   'bride',
#   'tormented',
#   'the',
#   'memory',
#   'her',
#   'husband',
#   "'s",
#   'dead',
#   'first',
#   'wife',
#   '.'],
#  ['renton',
#   ',',
#   'deeply',
#   'immersed',
#   'the',
#   'edinburgh',
#   'drug',
#   'scene',
#   ',',
#   'tries',
#   'clean',
#   'and',
#   'get',
#   'out',
#   ',',
#   'despite',
#   'the',
#   'allure',
#   'the',
#   'drugs',
#   'and',
#   'influence',
#   'friends',
#   '.'],
#  ['in-depth',
#   'examination',
#   'the',
#   'ways',
#   'which',
#   'the',
#   'u.s.',
#   'vietnam',
#   'war',
#   'impacts',
#   'and',
#   'disrupts',
#   'the',
#   'lives',
#   'people',
#   'small',
#   'industrial',
#   'town',
#   'pennsylvania',
#   '.'],
#  ['man', 'refuses', 'conform', 'life', 'rural', 'prison', '.'],
#  ['disgruntled',
#   'korean',
#   'war',
#   'veteran',
#   'walt',
#   'kowalski',
#   'sets',
#   'out',
#   'reform',
#   'his',
#   'neighbor',
#   ',',
#   'hmong',
#   'teenager',
#   'who',
#   'tried',
#   'steal',
#   'kowalski',
#   "'s",
#   'prized',
#   'possession',
#   ':',
#   '1972',
#   'gran',
#   'torino',
#   '.'],
#  ['``',
#   'the',
#   'dude',
#   "''",
#   'lebowski',
#   ',',
#   'mistaken',
#   'for',
#   'millionaire',
#   'lebowski',
#   ',',
#   'seeks',
#   'restitution',
#   'for',
#   'his',
#   'ruined',
#   'rug',
#   'and',
#   'enlists',
#   'his',
#   'bowling',
#   'buddies',
#   'help',
#   'get',
#   '.'],
#  ['research',
#   'facility',
#   'antarctica',
#   'comes',
#   'across',
#   'alien',
#   'force',
#   'that',
#   'can',
#   'become',
#   'anything',
#   'touches',
#   'with',
#   '100',
#   '%',
#   'accuracy',
#   '.',
#   'the',
#   'members',
#   'must',
#   'now',
#   'find',
#   'out',
#   'who',
#   "'s",
#   'human',
#   'and',
#   'who',
#   "'s",
#   'not',
#   'before',
#   "'s",
#   'too',
#   'late',
#   '.'],
#  ['spoiled',
#   'heiress',
#   'running',
#   'away',
#   'from',
#   'her',
#   'family',
#   'helped',
#   'man',
#   'who',
#   'actually',
#   'reporter',
#   'need',
#   'story',
#   '.'],
#  ['jerry',
#   'lundegaard',
#   "'s",
#   'inept',
#   'crime',
#   'falls',
#   'apart',
#   'due',
#   'his',
#   'and',
#   'his',
#   'henchmen',
#   "'s",
#   'bungling',
#   'and',
#   'the',
#   'persistent',
#   'police',
#   'work',
#   'the',
#   'quite',
#   'pregnant',
#   'marge',
#   'gunderson',
#   '.'],
#  ['boy',
#   'who',
#   'communicates',
#   'with',
#   'spirits',
#   'that',
#   "n't",
#   'know',
#   'they',
#   "'re",
#   'dead',
#   'seeks',
#   'the',
#   'help',
#   'disheartened',
#   'child',
#   'psychologist',
#   '.'],
#  ['after',
#   'his',
#   'son',
#   'captured',
#   'the',
#   'great',
#   'barrier',
#   'reef',
#   'and',
#   'taken',
#   'sydney',
#   ',',
#   'timid',
#   'clownfish',
#   'sets',
#   'out',
#   'journey',
#   'bring',
#   'him',
#   'home',
#   '.'],
#  ['tale',
#   'friendship',
#   'between',
#   'two',
#   'unlikely',
#   'pen',
#   'pals',
#   ':',
#   'mary',
#   ',',
#   'lonely',
#   ',',
#   'eight-year-old',
#   'girl',
#   'living',
#   'the',
#   'suburbs',
#   'melbourne',
#   ',',
#   'and',
#   'max',
#   ',',
#   'forty-four-year',
#   'old',
#   ',',
#   'severely',
#   'obese',
#   'man',
#   'living',
#   'new',
#   'york',
#   '.'],
#  ['violence',
#   'and',
#   'mayhem',
#   'ensue',
#   'after',
#   'hunter',
#   'stumbles',
#   'upon',
#   'drug',
#   'deal',
#   'gone',
#   'wrong',
#   'and',
#   'more',
#   'than',
#   'two',
#   'million',
#   'dollars',
#   'cash',
#   'near',
#   'the',
#   'rio',
#   'grande',
#   '.'],
#  ['hapless',
#   'young',
#   'viking',
#   'who',
#   'aspires',
#   'hunt',
#   'dragons',
#   'becomes',
#   'the',
#   'unlikely',
#   'friend',
#   'young',
#   'dragon',
#   'himself',
#   ',',
#   'and',
#   'learns',
#   'there',
#   'may',
#   'more',
#   'the',
#   'creatures',
#   'than',
#   'assumed',
#   '.'],
#  ['story',
#   'family',
#   ',',
#   'religion',
#   ',',
#   'hatred',
#   ',',
#   'oil',
#   'and',
#   'madness',
#   ',',
#   'focusing',
#   'turn-of-the-century',
#   'prospector',
#   'the',
#   'early',
#   'days',
#   'the',
#   'business',
#   '.'],
#  ['after',
#   'graduating',
#   'from',
#   'emory',
#   'university',
#   ',',
#   'top',
#   'student',
#   'and',
#   'athlete',
#   'christopher',
#   'mccandless',
#   'abandons',
#   'his',
#   'possessions',
#   ',',
#   'gives',
#   'his',
#   'entire',
#   '$',
#   '24,000',
#   'savings',
#   'account',
#   'charity',
#   'and',
#   'hitchhikes',
#   'alaska',
#   'live',
#   'the',
#   'wilderness',
#   '.',
#   'along',
#   'the',
#   'way',
#   ',',
#   'christopher',
#   'encounters',
#   'series',
#   'characters',
#   'that',
#   'shape',
#   'his',
#   'life',
#   '.'],
#  ['the',
#   'bride',
#   'wakens',
#   'from',
#   'four-year',
#   'coma',
#   '.',
#   'the',
#   'child',
#   'she',
#   'carried',
#   'her',
#   'womb',
#   'gone',
#   '.',
#   'now',
#   'she',
#   'must',
#   'wreak',
#   'vengeance',
#   'the',
#   'team',
#   'assassins',
#   'who',
#   'betrayed',
#   'her',
#   '-',
#   'team',
#   'she',
#   'was',
#   'once',
#   'part',
#   '.'],
#  ['with',
#   'his',
#   'wife',
#   "'s",
#   'disappearance',
#   'having',
#   'become',
#   'the',
#   'focus',
#   'intense',
#   'media',
#   'circus',
#   ',',
#   'man',
#   'sees',
#   'the',
#   'spotlight',
#   'turned',
#   'him',
#   'when',
#   "'s",
#   'suspected',
#   'that',
#   'may',
#   'not',
#   'innocent',
#   '.'],
#  ['brian',
#   'born',
#   'the',
#   'original',
#   'christmas',
#   ',',
#   'the',
#   'stable',
#   'next',
#   'door',
#   '.',
#   'spends',
#   'his',
#   'life',
#   'being',
#   'mistaken',
#   'for',
#   'messiah',
#   '.'],
#  ['television',
#   'network',
#   'cynically',
#   'exploits',
#   'deranged',
#   'former',
#   'anchor',
#   "'s",
#   'ravings',
#   'and',
#   'revelations',
#   'about',
#   'the',
#   'news',
#   'media',
#   'for',
#   'its',
#   'own',
#   'profit',
#   '.'],
#  ['1954',
#   ',',
#   'u.s.',
#   'marshal',
#   'investigates',
#   'the',
#   'disappearance',
#   'murderess',
#   'who',
#   'escaped',
#   'from',
#   'hospital',
#   'for',
#   'the',
#   'criminally',
#   'insane',
#   '.'],
#  ['man',
#   "'s",
#   'coerced',
#   'confession',
#   'ira',
#   'bombing',
#   'did',
#   'not',
#   'commit',
#   'results',
#   'the',
#   'imprisonment',
#   'his',
#   'father',
#   'well',
#   '.',
#   'english',
#   'lawyer',
#   'fights',
#   'free',
#   'them',
#   '.'],
#  ['the',
#   'merciless',
#   '1970s',
#   'rivalry',
#   'between',
#   'formula',
#   'one',
#   'rivals',
#   'james',
#   'hunt',
#   'and',
#   'niki',
#   'lauda',
#   '.'],
#  ['paul',
#   'rusesabagina',
#   'was',
#   'hotel',
#   'manager',
#   'who',
#   'housed',
#   'over',
#   'thousand',
#   'tutsi',
#   'refugees',
#   'during',
#   'their',
#   'struggle',
#   'against',
#   'the',
#   'hutu',
#   'militia',
#   'rwanda',
#   '.'],
#  ['young',
#   'recruit',
#   'vietnam',
#   'faces',
#   'moral',
#   'crisis',
#   'when',
#   'confronted',
#   'with',
#   'the',
#   'horrors',
#   'war',
#   'and',
#   'the',
#   'duality',
#   'man',
#   '.'],
#  ['ben',
#   ',',
#   'young',
#   'irish',
#   'boy',
#   ',',
#   'and',
#   'his',
#   'little',
#   'sister',
#   'saoirse',
#   ',',
#   'girl',
#   'who',
#   'can',
#   'turn',
#   'into',
#   'seal',
#   ',',
#   'go',
#   'adventure',
#   'free',
#   'the',
#   'fairies',
#   'and',
#   'save',
#   'the',
#   'spirit',
#   'world',
#   '.'],
#  ['when',
#   'jewish',
#   'prince',
#   'betrayed',
#   'and',
#   'sent',
#   'into',
#   'slavery',
#   'roman',
#   'friend',
#   ',',
#   'regains',
#   'his',
#   'freedom',
#   'and',
#   'comes',
#   'back',
#   'for',
#   'revenge',
#   '.'],
#  ['after',
#   'the',
#   'death',
#   'friend',
#   ',',
#   'writer',
#   'recounts',
#   'boyhood',
#   'journey',
#   'find',
#   'the',
#   'body',
#   'missing',
#   'boy',
#   '.'],
#  ['college',
#   'professor',
#   "'s",
#   'bond',
#   'with',
#   'the',
#   'abandoned',
#   'dog',
#   'takes',
#   'into',
#   'his',
#   'home',
#   '.'],
#  ['distant',
#   'poor',
#   'relative',
#   'the',
#   'duke',
#   "d'ascoyne",
#   'plots',
#   'inherit',
#   'the',
#   'title',
#   'murdering',
#   'the',
#   'eight',
#   'other',
#   'heirs',
#   'who',
#   'stand',
#   'ahead',
#   'him',
#   'the',
#   'line',
#   'succession',
#   '.'],
#  ['private',
#   'detective',
#   'takes',
#   'case',
#   'that',
#   'involves',
#   'him',
#   'with',
#   'three',
#   'eccentric',
#   'criminals',
#   ',',
#   'gorgeous',
#   'liar',
#   ',',
#   'and',
#   'their',
#   'quest',
#   'for',
#   'priceless',
#   'statuette',
#   '.'],
#  ['two',
#   'western',
#   'bank/train',
#   'robbers',
#   'flee',
#   'bolivia',
#   'when',
#   'the',
#   'law',
#   'gets',
#   'too',
#   'close',
#   '.'],
#  ['baby',
#   'boy',
#   ',',
#   'discovered',
#   '1900',
#   'ocean',
#   'liner',
#   ',',
#   'grows',
#   'into',
#   'musical',
#   'prodigy',
#   ',',
#   'never',
#   'setting',
#   'foot',
#   'land',
#   '.'],
#  ['the',
#   'true',
#   'story',
#   'how',
#   'the',
#   'boston',
#   'globe',
#   'uncovered',
#   'the',
#   'massive',
#   'scandal',
#   'child',
#   'molestation',
#   'and',
#   'cover-up',
#   'within',
#   'the',
#   'local',
#   'catholic',
#   'archdiocese',
#   ',',
#   'shaking',
#   'the',
#   'entire',
#   'catholic',
#   'church',
#   'its',
#   'core',
#   '.'],
#  ['meeting',
#   'stranger',
#   'railway',
#   'station',
#   ',',
#   'woman',
#   'tempted',
#   'cheat',
#   'her',
#   'husband',
#   '.'],
#  ['three',
#   'world',
#   'war',
#   'ii',
#   'veterans',
#   'return',
#   'home',
#   'small-town',
#   'america',
#   'discover',
#   'that',
#   'they',
#   'and',
#   'their',
#   'families',
#   'have',
#   'been',
#   'irreparably',
#   'changed',
#   '.'],
#  ['poor',
#   'midwest',
#   'family',
#   'forced',
#   'off',
#   'their',
#   'land',
#   '.',
#   'they',
#   'travel',
#   'california',
#   ',',
#   'suffering',
#   'the',
#   'misfortunes',
#   'the',
#   'homeless',
#   'the',
#   'great',
#   'depression',
#   '.'],
#  ['the',
#   'antebellum',
#   'united',
#   'states',
#   ',',
#   'solomon',
#   'northup',
#   ',',
#   'free',
#   'black',
#   'man',
#   'from',
#   'upstate',
#   'new',
#   'york',
#   ',',
#   'abducted',
#   'and',
#   'sold',
#   'into',
#   'slavery',
#   '.'],
#  ['the',
#   'adventures',
#   'gustave',
#   'h',
#   ',',
#   'legendary',
#   'concierge',
#   'famous',
#   'hotel',
#   'from',
#   'the',
#   'fictional',
#   'republic',
#   'zubrowka',
#   'between',
#   'the',
#   'first',
#   'and',
#   'second',
#   'world',
#   'wars',
#   ',',
#   'and',
#   'zero',
#   'moustafa',
#   ',',
#   'the',
#   'lobby',
#   'boy',
#   'who',
#   'becomes',
#   'his',
#   'most',
#   'trusted',
#   'friend',
#   '.'],
#  ['woman',
#   'rebels',
#   'against',
#   'tyrannical',
#   'ruler',
#   'postapocalyptic',
#   'australia',
#   'search',
#   'for',
#   'her',
#   'home-land',
#   'with',
#   'the',
#   'help',
#   'group',
#   'female',
#   'prisoners',
#   ',',
#   'psychotic',
#   'worshipper',
#   ',',
#   'and',
#   'drifter',
#   'named',
#   'max',
#   '.'],
#  ['while',
#   'home',
#   'sick',
#   'bed',
#   ',',
#   'young',
#   'boy',
#   "'s",
#   'grandfather',
#   'reads',
#   'him',
#   'story',
#   'called',
#   'the',
#   'princess',
#   'bride',
#   '.'],
#  ['former',
#   'child',
#   'star',
#   'torments',
#   'her',
#   'paraplegic',
#   'sister',
#   'their',
#   'decaying',
#   'hollywood',
#   'mansion',
#   '.'],
#  ['determined',
#   'woman',
#   'works',
#   'with',
#   'hardened',
#   'boxing',
#   'trainer',
#   'become',
#   'professional',
#   '.'],
#  ['during',
#   'preview',
#   'tour',
#   ',',
#   'theme',
#   'park',
#   'suffers',
#   'major',
#   'power',
#   'breakdown',
#   'that',
#   'allows',
#   'its',
#   'cloned',
#   'dinosaur',
#   'exhibits',
#   'run',
#   'amok',
#   '.'],
#  ['stark',
#   ',',
#   'perverse',
#   'story',
#   'murder',
#   ',',
#   'kidnapping',
#   ',',
#   'and',
#   'police',
#   'corruption',
#   'mexican',
#   'border',
#   'town',
#   '.'],
#  ['peter',
#   'parker',
#   ',',
#   'with',
#   'the',
#   'help',
#   'his',
#   'mentor',
#   'tony',
#   'stark',
#   ',',
#   'tries',
#   'balance',
#   'his',
#   'life',
#   'ordinary',
#   'high',
#   'school',
#   'student',
#   'new',
#   'york',
#   'city',
#   'while',
#   'fighting',
#   'crime',
#   'his',
#   'superhero',
#   'alter',
#   'ego',
#   'spider-man',
#   'when',
#   'new',
#   'threat',
#   'emerges',
#   '.'],
#  ['young',
#   'man',
#   'and',
#   'woman',
#   'meet',
#   'train',
#   'europe',
#   ',',
#   'and',
#   'wind',
#   'spending',
#   'one',
#   'evening',
#   'together',
#   'vienna',
#   '.',
#   'unfortunately',
#   ',',
#   'both',
#   'know',
#   'that',
#   'this',
#   'will',
#   'probably',
#   'their',
#   'only',
#   'night',
#   'together',
#   '.'],
#  ['insurance',
#   'salesman/adjuster',
#   'discovers',
#   'his',
#   'entire',
#   'life',
#   'actually',
#   'television',
#   'show',
#   '.'],
#  ['harry',
#   ',',
#   'ron',
#   'and',
#   'hermione',
#   'search',
#   'for',
#   'voldemort',
#   "'s",
#   'remaining',
#   'horcruxes',
#   'their',
#   'effort',
#   'destroy',
#   'the',
#   'dark',
#   'lord',
#   'the',
#   'final',
#   'battle',
#   'rages',
#   'hogwarts',
#   '.'],
#  ['three',
#   'decades',
#   'after',
#   'the',
#   'empire',
#   "'s",
#   'defeat',
#   ',',
#   'new',
#   'threat',
#   'arises',
#   'the',
#   'militant',
#   'first',
#   'order',
#   '.',
#   'stormtrooper',
#   'defector',
#   'finn',
#   'and',
#   'spare',
#   'parts',
#   'scavenger',
#   'rey',
#   'are',
#   'caught',
#   'the',
#   'resistance',
#   "'s",
#   'search',
#   'for',
#   'the',
#   'missing',
#   'luke',
#   'skywalker',
#   '.'],
#  ['travis',
#   'henderson',
#   ',',
#   'aimless',
#   'drifter',
#   'who',
#   'has',
#   'been',
#   'missing',
#   'for',
#   'four',
#   'years',
#   ',',
#   'wanders',
#   'out',
#   'the',
#   'desert',
#   'and',
#   'must',
#   'reconnect',
#   'with',
#   'society',
#   ',',
#   'himself',
#   ',',
#   'his',
#   'life',
#   ',',
#   'and',
#   'his',
#   'family',
#   '.'],
#  ['1951',
#   ',',
#   'group',
#   'high',
#   'schoolers',
#   'come',
#   'age',
#   'bleak',
#   ',',
#   'isolated',
#   ',',
#   'atrophied',
#   'west',
#   'texas',
#   'town',
#   'that',
#   'slowly',
#   'dying',
#   ',',
#   'both',
#   'culturally',
#   'and',
#   'economically',
#   '.'],
#  ['gandhi',
#   "'s",
#   'character',
#   'fully',
#   'explained',
#   'man',
#   'nonviolence',
#   '.',
#   'through',
#   'his',
#   'patience',
#   ',',
#   'able',
#   'drive',
#   'the',
#   'british',
#   'out',
#   'the',
#   'subcontinent',
#   '.',
#   'and',
#   'the',
#   'stubborn',
#   'nature',
#   'jinnah',
#   'and',
#   'his',
#   'commitment',
#   'towards',
#   'pakistan',
#   'portrayed',
#   '.'],
#  ['irish',
#   'rogue',
#   'wins',
#   'the',
#   'heart',
#   'rich',
#   'widow',
#   'and',
#   'assumes',
#   'her',
#   'dead',
#   'husband',
#   "'s",
#   'aristocratic',
#   'position',
#   '18th-century',
#   'england',
#   '.'],
#  ['rocky',
#   'balboa',
#   ',',
#   'small-time',
#   'boxer',
#   ',',
#   'gets',
#   'supremely',
#   'rare',
#   'chance',
#   'fight',
#   'heavy-weight',
#   'champion',
#   'apollo',
#   'creed',
#   'bout',
#   'which',
#   'strives',
#   'go',
#   'the',
#   'distance',
#   'for',
#   'his',
#   'self-respect',
#   '.'],
#  ['neurotic',
#   'new',
#   'york',
#   'comedian',
#   'alvy',
#   'singer',
#   'falls',
#   'love',
#   'with',
#   'the',
#   'ditzy',
#   'annie',
#   'hall',
#   '.'],
#  ['when',
#   'keller',
#   'dover',
#   "'s",
#   'daughter',
#   'and',
#   'her',
#   'friend',
#   'go',
#   'missing',
#   ',',
#   'takes',
#   'matters',
#   'into',
#   'his',
#   'own',
#   'hands',
#   'the',
#   'police',
#   'pursue',
#   'multiple',
#   'leads',
#   'and',
#   'the',
#   'pressure',
#   'mounts',
#   '.'],
#  ['troubled',
#   'teenager',
#   'plagued',
#   'visions',
#   'man',
#   'large',
#   'rabbit',
#   'suit',
#   'who',
#   'manipulates',
#   'him',
#   'commit',
#   'series',
#   'crimes',
#   ',',
#   'after',
#   'narrowly',
#   'escapes',
#   'bizarre',
#   'accident',
#   '.'],
#  ['the',
#   'story',
#   "'frank",
#   'abagnale',
#   'jr.',
#   ',',
#   'before',
#   'his',
#   '19th',
#   'birthday',
#   ',',
#   'successfully',
#   'forged',
#   'millions',
#   'dollars',
#   "'",
#   'worth',
#   'checks',
#   'while',
#   'posing',
#   'pan',
#   'pilot',
#   ',',
#   'doctor',
#   ',',
#   'and',
#   'legal',
#   'prosecutor',
#   'seasoned',
#   'and',
#   'dedicated',
#   'fbi',
#   'agent',
#   'pursues',
#   'him',
#   '.'],
#  ['senator',
#   ',',
#   'who',
#   'became',
#   'famous',
#   'for',
#   'killing',
#   'notorious',
#   'outlaw',
#   ',',
#   'returns',
#   'for',
#   'the',
#   'funeral',
#   'old',
#   'friend',
#   'and',
#   'tells',
#   'the',
#   'truth',
#   'about',
#   'his',
#   'deed',
#   '.'],
#  ['police',
#   'detective',
#   'falls',
#   'love',
#   'with',
#   'the',
#   'woman',
#   'whose',
#   'murder',
#   'investigating',
#   '.'],
#  ['order',
#   'power',
#   'the',
#   'city',
#   ',',
#   'monsters',
#   'have',
#   'scare',
#   'children',
#   'that',
#   'they',
#   'scream',
#   '.',
#   'however',
#   ',',
#   'the',
#   'children',
#   'are',
#   'toxic',
#   'the',
#   'monsters',
#   ',',
#   'and',
#   'after',
#   'child',
#   'gets',
#   'through',
#   ',',
#   '2',
#   'monsters',
#   'realize',
#   'things',
#   'may',
#   'not',
#   'what',
#   'they',
#   'think',
#   '.'],
#  ['jason',
#   'bourne',
#   'dodges',
#   'ruthless',
#   'cia',
#   'official',
#   'and',
#   'his',
#   'agents',
#   'from',
#   'new',
#   'assassination',
#   'program',
#   'while',
#   'searching',
#   'for',
#   'the',
#   'origins',
#   'his',
#   'life',
#   'trained',
#   'killer',
#   '.'],
#  ['brick',
#   ',',
#   'alcoholic',
#   'ex-football',
#   'player',
#   ',',
#   'drinks',
#   'his',
#   'days',
#   'away',
#   'and',
#   'resists',
#   'the',
#   'affections',
#   'his',
#   'wife',
#   ',',
#   'maggie',
#   '.',
#   'his',
#   'reunion',
#   'with',
#   'his',
#   'father',
#   ',',
#   'big',
#   'daddy',
#   ',',
#   'who',
#   'dying',
#   'cancer',
#   ',',
#   'jogs',
#   'host',
#   'memories',
#   'and',
#   'revelations',
#   'for',
#   'both',
#   'father',
#   'and',
#   'son',
#   '.'],
#  ['dorothy',
#   'gale',
#   'swept',
#   'away',
#   'from',
#   'farm',
#   'kansas',
#   'magical',
#   'land',
#   'oz',
#   'tornado',
#   'and',
#   'embarks',
#   'quest',
#   'with',
#   'her',
#   'new',
#   'friends',
#   'see',
#   'the',
#   'wizard',
#   'who',
#   'can',
#   'help',
#   'her',
#   'return',
#   'home',
#   'kansas',
#   'and',
#   'help',
#   'her',
#   'friends',
#   'well',
#   '.'],
#  ['man',
#   'who',
#   'loves',
#   'games',
#   'and',
#   'theater',
#   'invites',
#   'his',
#   'wife',
#   "'s",
#   'lover',
#   'meet',
#   'him',
#   ',',
#   'setting',
#   'battle',
#   'wits',
#   'with',
#   'potentially',
#   'deadly',
#   'results',
#   '.'],
#  ['bored',
#   'and',
#   'sheltered',
#   'princess',
#   'escapes',
#   'her',
#   'guardians',
#   'and',
#   'falls',
#   'love',
#   'with',
#   'american',
#   'newsman',
#   'rome',
#   '.'],
#  ['private',
#   'eye',
#   'escapes',
#   'his',
#   'past',
#   'run',
#   'gas',
#   'station',
#   'small',
#   'town',
#   ',',
#   'but',
#   'his',
#   'past',
#   'catches',
#   'with',
#   'him',
#   '.',
#   'now',
#   'must',
#   'return',
#   'the',
#   'big',
#   'city',
#   'world',
#   'danger',
#   ',',
#   'corruption',
#   ',',
#   'double',
#   'crosses',
#   'and',
#   'duplicitous',
#   'dames',
#   '.'],
#  ['murder',
#   'trial',
#   ',',
#   'the',
#   'defendant',
#   'says',
#   'suffered',
#   'temporary',
#   'insanity',
#   'after',
#   'the',
#   'victim',
#   'raped',
#   'his',
#   'wife',
#   '.',
#   'what',
#   'the',
#   'truth',
#   ',',
#   'and',
#   'will',
#   'win',
#   'his',
#   'case',
#   '?'],
#  ['bitter',
#   ',',
#   'aging',
#   'couple',
#   ',',
#   'with',
#   'the',
#   'help',
#   'alcohol',
#   ',',
#   'use',
#   'young',
#   'couple',
#   'fuel',
#   'anguish',
#   'and',
#   'emotional',
#   'pain',
#   'towards',
#   'each',
#   'other',
#   '.'],
#  ['seemingly',
#   'indestructible',
#   'humanoid',
#   'cyborg',
#   'sent',
#   'from',
#   '2029',
#   '1984',
#   'assassinate',
#   'waitress',
#   ',',
#   'whose',
#   'unborn',
#   'son',
#   'will',
#   'lead',
#   'humanity',
#   'war',
#   'against',
#   'the',
#   'machines',
#   ',',
#   'while',
#   'soldier',
#   'from',
#   'that',
#   'war',
#   'sent',
#   'protect',
#   'her',
#   'all',
#   'costs',
#   '.'],
#  ['weatherman',
#   'finds',
#   'himself',
#   'inexplicably',
#   'living',
#   'the',
#   'same',
#   'day',
#   'over',
#   'and',
#   'over',
#   'again',
#   '.'],
#  ['aspiring',
#   'author',
#   'during',
#   'the',
#   'civil',
#   'rights',
#   'movement',
#   'the',
#   '1960s',
#   'decides',
#   'write',
#   'book',
#   'detailing',
#   'the',
#   'african',
#   'american',
#   'maids',
#   "'",
#   'point',
#   'view',
#   'the',
#   'white',
#   'families',
#   'for',
#   'which',
#   'they',
#   'work',
#   ',',
#   'and',
#   'the',
#   'hardships',
#   'they',
#   'go',
#   'through',
#   'daily',
#   'basis',
#   '.'],
#  ['psychotic',
#   'socialite',
#   'confronts',
#   'pro',
#   'tennis',
#   'star',
#   'with',
#   'theory',
#   'how',
#   'two',
#   'complete',
#   'strangers',
#   'can',
#   'get',
#   'away',
#   'with',
#   'murder',
#   '-',
#   'theory',
#   'that',
#   'plans',
#   'implement',
#   '.'],
#  ['religious',
#   'fanatic',
#   'marries',
#   'gullible',
#   'widow',
#   'whose',
#   'young',
#   'children',
#   'are',
#   'reluctant',
#   'tell',
#   'him',
#   'where',
#   'their',
#   'real',
#   'daddy',
#   'hid',
#   '$',
#   '10,000',
#   "'d",
#   'stolen',
#   'robbery',
#   '.'],
#  ['young',
#   'soldier',
#   'faces',
#   'profound',
#   'disillusionment',
#   'the',
#   'soul-destroying',
#   'horror',
#   'world',
#   'war',
#   '.'],
#  ['young',
#   'woman',
#   'whose',
#   'father',
#   'has',
#   'been',
#   'imprisoned',
#   'terrifying',
#   'beast',
#   'offers',
#   'herself',
#   'his',
#   'place',
#   ',',
#   'unaware',
#   'that',
#   'her',
#   'captor',
#   'actually',
#   'prince',
#   ',',
#   'physically',
#   'altered',
#   'magic',
#   'spell',
#   '.'],
#  ['five-year-old',
#   'indian',
#   'boy',
#   'gets',
#   'lost',
#   'the',
#   'streets',
#   'calcutta',
#   ',',
#   'thousands',
#   'kilometers',
#   'from',
#   'home',
#   '.',
#   'survives',
#   'many',
#   'challenges',
#   'before',
#   'being',
#   'adopted',
#   'couple',
#   'australia',
#   '.',
#   '25',
#   'years',
#   'later',
#   ',',
#   'sets',
#   'out',
#   'find',
#   'his',
#   'lost',
#   'family',
#   '.'],
#  ['future',
#   'world',
#   'devastated',
#   'disease',
#   ',',
#   'convict',
#   'sent',
#   'back',
#   'time',
#   'gather',
#   'information',
#   'about',
#   'the',
#   'man-made',
#   'virus',
#   'that',
#   'wiped',
#   'out',
#   'most',
#   'the',
#   'human',
#   'population',
#   'the',
#   'planet',
#   '.'],
#  ['group',
#   'intergalactic',
#   'criminals',
#   'are',
#   'forced',
#   'work',
#   'together',
#   'stop',
#   'fanatical',
#   'warrior',
#   'from',
#   'taking',
#   'control',
#   'the',
#   'universe',
#   '.'],
#  ['man',
#   'robs',
#   'bank',
#   'pay',
#   'for',
#   'his',
#   'lover',
#   "'s",
#   'operation',
#   ';',
#   'turns',
#   'into',
#   'hostage',
#   'situation',
#   'and',
#   'media',
#   'circus',
#   '.'],
#  ['giant',
#   'great',
#   'white',
#   'shark',
#   'arrives',
#   'the',
#   'shores',
#   'new',
#   'england',
#   'beach',
#   'resort',
#   'and',
#   'wreaks',
#   'havoc',
#   'with',
#   'bloody',
#   'attacks',
#   'swimmers',
#   ',',
#   'until',
#   'local',
#   'sheriff',
#   'teams',
#   'with',
#   'marine',
#   'biologist',
#   'and',
#   'old',
#   'seafarer',
#   'hunt',
#   'the',
#   'monster',
#   'down',
#   '.'],
#  ['city',
#   'anthropomorphic',
#   'animals',
#   ',',
#   'rookie',
#   'bunny',
#   'cop',
#   'and',
#   'cynical',
#   'con',
#   'artist',
#   'fox',
#   'must',
#   'work',
#   'together',
#   'uncover',
#   'conspiracy',
#   '.'],
#  ['the',
#   'guardians',
#   'must',
#   'fight',
#   'keep',
#   'their',
#   'newfound',
#   'family',
#   'together',
#   'they',
#   'unravel',
#   'the',
#   'mystery',
#   'peter',
#   'quill',
#   "'s",
#   'true',
#   'parentage',
#   '.'],
#  ['blacksmith',
#   'will',
#   'turner',
#   'teams',
#   'with',
#   'eccentric',
#   'pirate',
#   '``',
#   'captain',
#   "''",
#   'jack',
#   'sparrow',
#   'save',
#   'his',
#   'love',
#   ',',
#   'the',
#   'governor',
#   "'s",
#   'daughter',
#   ',',
#   'from',
#   'jack',
#   "'s",
#   'former',
#   'pirate',
#   'allies',
#   ',',
#   'who',
#   'are',
#   'now',
#   'undead',
#   '.'],
#  ['nine',
#   'years',
#   'after',
#   'jesse',
#   'and',
#   'celine',
#   'first',
#   'met',
#   ',',
#   'they',
#   'encounter',
#   'each',
#   'other',
#   'again',
#   'the',
#   'french',
#   'leg',
#   'jesse',
#   "'s",
#   'book',
#   'tour',
#   '.'],
#  ['during',
#   'world',
#   'war',
#   'ii',
#   ',',
#   'mathematician',
#   'alan',
#   'turing',
#   'tries',
#   'crack',
#   'the',
#   'enigma',
#   'code',
#   'with',
#   'help',
#   'from',
#   'fellow',
#   'mathematicians',
#   '.'],
#  ['american',
#   'grandson',
#   'the',
#   'infamous',
#   'scientist',
#   ',',
#   'struggling',
#   'prove',
#   'that',
#   'not',
#   'insane',
#   'people',
#   'believe',
#   ',',
#   'invited',
#   'transylvania',
#   ',',
#   'where',
#   'discovers',
#   'the',
#   'process',
#   'that',
#   'reanimates',
#   'dead',
#   'body',
#   '.'],
#  ['when',
#   'two',
#   'escaping',
#   'american',
#   'world',
#   'war',
#   'ii',
#   'prisoners',
#   'are',
#   'killed',
#   ',',
#   'the',
#   'german',
#   'pow',
#   'camp',
#   'barracks',
#   'black',
#   'marketeer',
#   ',',
#   'j.j.',
#   'sefton',
#   ',',
#   'suspected',
#   'being',
#   'informer',
#   '.'],
#  ['woman',
#   'the',
#   'run',
#   'from',
#   'the',
#   'mob',
#   'reluctantly',
#   'accepted',
#   'small',
#   'colorado',
#   'town',
#   '.',
#   'exchange',
#   ',',
#   'she',
#   'agrees',
#   'work',
#   'for',
#   'them',
#   '.',
#   'search',
#   'visits',
#   'town',
#   ',',
#   'she',
#   'finds',
#   'out',
#   'that',
#   'their',
#   'support',
#   'has',
#   'price',
#   '.',
#   'yet',
#   'her',
#   'dangerous',
#   'secret',
#   'never',
#   'far',
#   'away',
#   '...'],
#  ['english',
#   'teacher',
#   'john',
#   'keating',
#   'inspires',
#   'his',
#   'students',
#   'look',
#   'poetry',
#   'with',
#   'different',
#   'perspective',
#   'authentic',
#   'knowledge',
#   'and',
#   'feelings',
#   '.'],
#  ['marshal',
#   'will',
#   'kane',
#   ',',
#   'personally',
#   'compelled',
#   'face',
#   'his',
#   'returning',
#   'deadly',
#   'enemy',
#   'frank',
#   'miller',
#   ',',
#   'finds',
#   'that',
#   'his',
#   'fellow',
#   'townspeople',
#   'refuse',
#   'help',
#   'him',
#   '.'],
#  ['man',
#   'befriends',
#   'fellow',
#   'criminal',
#   'the',
#   'two',
#   'them',
#   'begin',
#   'serving',
#   'their',
#   'sentence',
#   'dreadful',
#   'prison',
#   'island',
#   ',',
#   'which',
#   'inspires',
#   'the',
#   'man',
#   'plot',
#   'his',
#   'escape',
#   '.'],
#  ['disturbed',
#   'blanche',
#   'dubois',
#   'moves',
#   'with',
#   'her',
#   'sister',
#   'new',
#   'orleans',
#   'and',
#   'tormented',
#   'her',
#   'brutish',
#   'brother-in-law',
#   'while',
#   'her',
#   'reality',
#   'crumbles',
#   'around',
#   'her',
#   '.'],
#  ['drama',
#   'critic',
#   'learns',
#   'his',
#   'wedding',
#   'day',
#   'that',
#   'his',
#   'beloved',
#   'maiden',
#   'aunts',
#   'are',
#   'homicidal',
#   'maniacs',
#   ',',
#   'and',
#   'that',
#   'insanity',
#   'runs',
#   'his',
#   'family',
#   '.'],
#  ['film',
#   'that',
#   'explores',
#   'the',
#   'dark',
#   'and',
#   'miserable',
#   'town',
#   ',',
#   'basin',
#   'city',
#   ',',
#   'and',
#   'tells',
#   'the',
#   'story',
#   'three',
#   'different',
#   'people',
#   ',',
#   'all',
#   'caught',
#   'violent',
#   'corruption',
#   '.'],
#  ['up-and-coming',
#   'pool',
#   'player',
#   'plays',
#   'long-time',
#   'champion',
#   'single',
#   'high-stakes',
#   'match',
#   '.'],
#  ['sly',
#   'business',
#   'manager',
#   'and',
#   'two',
#   'wacky',
#   'friends',
#   'two',
#   'opera',
#   'singers',
#   'help',
#   'them',
#   'achieve',
#   'success',
#   'while',
#   'humiliating',
#   'their',
#   'stuffy',
#   'and',
#   'snobbish',
#   'enemies',
#   '.'],
#  ['crooks', 'plan', 'and', 'execute', 'daring', 'race-track', 'robbery', '.'],
#  ['earth',
#   "'s",
#   'mightiest',
#   'heroes',
#   'must',
#   'come',
#   'together',
#   'and',
#   'learn',
#   'fight',
#   'team',
#   'they',
#   'are',
#   'stop',
#   'the',
#   'mischievous',
#   'loki',
#   'and',
#   'his',
#   'alien',
#   'army',
#   'from',
#   'enslaving',
#   'humanity',
#   '.'],
#  ['woman',
#   'asked',
#   'spy',
#   'group',
#   'nazi',
#   'friends',
#   'south',
#   'america',
#   '.',
#   'how',
#   'far',
#   'will',
#   'she',
#   'have',
#   'go',
#   'ingratiate',
#   'herself',
#   'with',
#   'them',
#   '?'],
#  ['due',
#   'his',
#   'insistence',
#   'that',
#   'has',
#   'invisible',
#   'six',
#   'foot-tall',
#   'rabbit',
#   'for',
#   'best',
#   'friend',
#   ',',
#   'whimsical',
#   'middle-aged',
#   'man',
#   'thought',
#   'his',
#   'family',
#   'insane',
#   '-',
#   'but',
#   'may',
#   'wiser',
#   'than',
#   'anyone',
#   'knows',
#   '.'],
#  ['astronaut',
#   'becomes',
#   'stranded',
#   'mars',
#   'after',
#   'his',
#   'team',
#   'assume',
#   'him',
#   'dead',
#   ',',
#   'and',
#   'must',
#   'rely',
#   'his',
#   'ingenuity',
#   'find',
#   'way',
#   'signal',
#   'earth',
#   'that',
#   'alive',
#   '.'],
#  ['when',
#   'teenage',
#   'girl',
#   'possessed',
#   'mysterious',
#   'entity',
#   ',',
#   'her',
#   'mother',
#   'seeks',
#   'the',
#   'help',
#   'two',
#   'priests',
#   'save',
#   'her',
#   'daughter',
#   '.'],
#  ['small-town',
#   'sheriff',
#   'the',
#   'american',
#   'west',
#   'enlists',
#   'the',
#   'help',
#   'cripple',
#   ',',
#   'drunk',
#   ',',
#   'and',
#   'young',
#   'gunfighter',
#   'his',
#   'efforts',
#   'hold',
#   'jail',
#   'the',
#   'brother',
#   'the',
#   'local',
#   'bad',
#   'guy',
#   '.'],
#  ['when',
#   'rich',
#   'woman',
#   "'s",
#   'ex-husband',
#   'and',
#   'tabloid-type',
#   'reporter',
#   'turn',
#   'just',
#   'before',
#   'her',
#   'planned',
#   'remarriage',
#   ',',
#   'she',
#   'begins',
#   'learn',
#   'the',
#   'truth',
#   'about',
#   'herself',
#   '.'],
#  ['two',
#   'young',
#   'men',
#   'strangle',
#   'their',
#   '``',
#   'inferior',
#   "''",
#   'classmate',
#   ',',
#   'hide',
#   'his',
#   'body',
#   'their',
#   'apartment',
#   ',',
#   'and',
#   'invite',
#   'his',
#   'friends',
#   'and',
#   'family',
#   'dinner',
#   'party',
#   'means',
#   'challenge',
#   'the',
#   '``',
#   'perfection',
#   "''",
#   'their',
#   'crime',
#   '.'],
#  ['private',
#   'detective',
#   'philip',
#   'marlowe',
#   'hired',
#   'rich',
#   'family',
#   '.',
#   'before',
#   'the',
#   'complex',
#   'case',
#   'over',
#   ',',
#   "'s",
#   'seen',
#   'murder',
#   ',',
#   'blackmail',
#   ',',
#   'and',
#   'what',
#   'might',
#   'love',
#   '.'],
#  ['confined',
#   'but',
#   'troubled',
#   'rock',
#   'star',
#   'descends',
#   'into',
#   'madness',
#   'the',
#   'midst',
#   'his',
#   'physical',
#   'and',
#   'social',
#   'isolation',
#   'from',
#   'everyone',
#   '.'],
#  ['the',
#   'story',
#   'king',
#   'george',
#   'vi',
#   'the',
#   'united',
#   'kingdom',
#   'great',
#   'britain',
#   'and',
#   'northern',
#   'ireland',
#   ',',
#   'his',
#   'impromptu',
#   'ascension',
#   'the',
#   'throne',
#   'and',
#   'the',
#   'speech',
#   'therapist',
#   'who',
#   'helped',
#   'the',
#   'unsure',
#   'monarch',
#   'become',
#   'worthy',
#   '.'],
#  ['the',
#   '1940s',
#   ',',
#   'young',
#   'boy',
#   'named',
#   'ralphie',
#   'attempts',
#   'convince',
#   'his',
#   'parents',
#   ',',
#   'his',
#   'teacher',
#   ',',
#   'and',
#   'santa',
#   'that',
#   'red',
#   'ryder',
#   'b.b',
#   '.',
#   'gun',
#   'really',
#   'the',
#   'perfect',
#   'christmas',
#   'gift',
#   '.'],
#  ['disillusioned',
#   'college',
#   'graduate',
#   'finds',
#   'himself',
#   'torn',
#   'between',
#   'his',
#   'older',
#   'lover',
#   'and',
#   'her',
#   'daughter',
#   '.'],
#  ['new',
#   'orleans',
#   'da',
#   'discovers',
#   'there',
#   "'s",
#   'more',
#   'the',
#   'kennedy',
#   'assassination',
#   'than',
#   'the',
#   'official',
#   'story',
#   '.'],
#  ['karl',
#   'childers',
#   ',',
#   'simple',
#   'man',
#   'hospitalized',
#   'since',
#   'his',
#   'childhood',
#   'murder',
#   'his',
#   'mother',
#   'and',
#   'her',
#   'lover',
#   ',',
#   'released',
#   'start',
#   'new',
#   'life',
#   'small',
#   'town',
#   '.'],
#  ['fisherman',
#   ',',
#   'smuggler',
#   ',',
#   'and',
#   'syndicate',
#   'businessmen',
#   'match',
#   'wits',
#   'over',
#   'the',
#   'possession',
#   'priceless',
#   'diamond',
#   '.'],
#  ['epic',
#   'mosaic',
#   'interrelated',
#   'characters',
#   'search',
#   'love',
#   ',',
#   'forgiveness',
#   ',',
#   'and',
#   'meaning',
#   'the',
#   'san',
#   'fernando',
#   'valley',
#   '.'],
#  ['selfish',
#   'yuppie',
#   'charlie',
#   'babbitt',
#   "'s",
#   'father',
#   'left',
#   'fortune',
#   'his',
#   'savant',
#   'brother',
#   'raymond',
#   'and',
#   'pittance',
#   'charlie',
#   ';',
#   'they',
#   'travel',
#   'cross-country',
#   '.'],
#  ['frontiersman',
#   'fur',
#   'trading',
#   'expedition',
#   'the',
#   '1820s',
#   'fights',
#   'for',
#   'survival',
#   'after',
#   'being',
#   'mauled',
#   'bear',
#   'and',
#   'left',
#   'for',
#   'dead',
#   'members',
#   'his',
#   'own',
#   'hunting',
#   'team',
#   '.'],
#  ['jack',
#   'skellington',
#   ',',
#   'king',
#   'halloween',
#   'town',
#   ',',
#   'discovers',
#   'christmas',
#   'town',
#   ',',
#   'but',
#   'his',
#   'attempts',
#   'bring',
#   'christmas',
#   'his',
#   'home',
#   'cause',
#   'confusion',
#   '.'],
#  ['former',
#   'prisoner',
#   'war',
#   'brainwashed',
#   'unwitting',
#   'assassin',
#   'for',
#   'international',
#   'communist',
#   'conspiracy',
#   '.'],
#  ['fast-talking',
#   'mercenary',
#   'with',
#   'morbid',
#   'sense',
#   'humor',
#   'subjected',
#   'rogue',
#   'experiment',
#   'that',
#   'leaves',
#   'him',
#   'with',
#   'accelerated',
#   'healing',
#   'powers',
#   'and',
#   'quest',
#   'for',
#   'revenge',
#   '.'],
#  ['aging',
#   'group',
#   'outlaws',
#   'look',
#   'for',
#   'one',
#   'last',
#   'big',
#   'score',
#   'the',
#   '``',
#   'traditional',
#   "''",
#   'american',
#   'west',
#   'disappearing',
#   'around',
#   'them',
#   '.'],
#  ['when',
#   'street',
#   'urchin',
#   'vies',
#   'for',
#   'the',
#   'love',
#   'beautiful',
#   'princess',
#   ',',
#   'uses',
#   'genie',
#   "'s",
#   'magic',
#   'power',
#   'make',
#   'himself',
#   'off',
#   'prince',
#   'order',
#   'marry',
#   'her',
#   '.'],
#  ['frustrated',
#   'son',
#   'tries',
#   'determine',
#   'the',
#   'fact',
#   'from',
#   'fiction',
#   'his',
#   'dying',
#   'father',
#   "'s",
#   'life',
#   '.'],
#  ['the',
#   'world',
#   'war',
#   'ii',
#   'phase',
#   'the',
#   'career',
#   'the',
#   'controversial',
#   'american',
#   'general',
#   ',',
#   'george',
#   's.',
#   'patton',
#   '.'],
#  ['the',
#   'desperate',
#   'life',
#   'chronic',
#   'alcoholic',
#   'followed',
#   'through',
#   'four-day',
#   'drinking',
#   'bout',
#   '.'],
#  ['20-something',
#   'supervising',
#   'staff',
#   'member',
#   'residential',
#   'treatment',
#   'facility',
#   'navigates',
#   'the',
#   'troubled',
#   'waters',
#   'that',
#   'world',
#   'alongside',
#   'her',
#   'co-worker',
#   'and',
#   'longtime',
#   'boyfriend',
#   '.'],
#  ['newspaper',
#   'editor',
#   'uses',
#   'every',
#   'trick',
#   'the',
#   'book',
#   'keep',
#   'his',
#   'ace',
#   'reporter',
#   'ex-wife',
#   'from',
#   'remarrying',
#   '.'],
#  ['old',
#   'man',
#   'makes',
#   'long',
#   'journey',
#   'lawn-mover',
#   'tractor',
#   'mend',
#   'his',
#   'relationship',
#   'with',
#   'ill',
#   'brother',
#   '.'],
#  ['mumbai',
#   'teen',
#   'reflects',
#   'his',
#   'upbringing',
#   'the',
#   'slums',
#   'when',
#   'accused',
#   'cheating',
#   'the',
#   'indian',
#   'version',
#   '``',
#   'who',
#   'wants',
#   'millionaire',
#   '?',
#   "''"]]

# %%
df['clean_plot'] = plot
df['clean_plot']
# Out:
# 0      [two, imprisoned, men, bond, over, number, yea...
# 1      [the, aging, patriarch, organized, crime, dyna...
# 2      [the, early, life, and, career, vito, corleone...
# 3      [when, the, menace, known, the, joker, emerges...
# 4      [jury, holdout, attempts, prevent, miscarriage...
#                              ...
# 245    [the, desperate, life, chronic, alcoholic, fol...
# 246    [20-something, supervising, staff, member, res...
# 247    [newspaper, editor, uses, every, trick, the, b...
# 248    [old, man, makes, long, journey, lawn-mover, t...
# 249    [mumbai, teen, reflects, his, upbringing, the,...
# Name: clean_plot, Length: 250, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0                     Title  Year     Rated   Released  Runtime  \
# 0           1  The Shawshank Redemption  1994         R  14-Oct-94  142 min
# 1           2             The Godfather  1972         R  24-Mar-72  175 min
# 2           3    The Godfather: Part II  1974         R  20-Dec-74  202 min
# 3           4           The Dark Knight  2008     PG-13  18-Jul-08  152 min
# 4           5              12 Angry Men  1957  APPROVED  01-Apr-57   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# 3  Jonathan Nolan (screenplay), Christopher Nolan...
# 4  Reginald Rose (story), Reginald Rose (screenplay)
#
#                                               Actors  \
# 0  Tim Robbins, Morgan Freeman, Bob Gunton, Willi...
# 1  Marlon Brando, Al Pacino, James Caan, Richard ...
# 2  Al Pacino, Robert Duvall, Diane Keaton, Robert...
# 3  Christian Bale, Heath Ledger, Aaron Eckhart, M...
# 4  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
#
#                                                 Plot  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# 2  The early life and career of Vito Corleone in ...
# 3  When the menace known as the Joker emerges fro...
# 4  A jury holdout attempts to prevent a miscarria...
#
#                                      Language  Country  \
# 0                                     English      USA
# 1                     English, Italian, Latin      USA
# 2  English, Italian, Spanish, Latin, Sicilian      USA
# 3                           English, Mandarin  USA, UK
# 4                                     English      USA
#
#                                               Awards  \
# 0  Nominated for 7 Oscars. Another 19 wins & 30 n...
# 1    Won 3 Oscars. Another 23 wins & 27 nominations.
# 2    Won 6 Oscars. Another 10 wins & 20 nominations.
# 3  Won 2 Oscars. Another 151 wins & 153 nominations.
# 4  Nominated for 3 Oscars. Another 16 wins & 8 no...
#
#                                               Poster           Ratings.Source  \
# 0  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 1  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 2  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 3  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
# 4  https://images-na.ssl-images-amazon.com/images...  Internet Movie Database
#
#   Ratings.Value  Metascore  imdbRating  imdbVotes     imdbID   Type  \
# 0        9.3/10       80.0         9.3  18,25,626  tt0111161  movie
# 1        9.2/10      100.0         9.2  12,43,444  tt0068646  movie
# 2        9.0/10       85.0         9.0   8,56,870  tt0071562  movie
# 3        9.0/10       82.0         9.0  18,02,351  tt0468569  movie
# 4        8.9/10       96.0         8.9   4,94,215  tt0050083  movie
#
#    tomatoMeter  tomatoImage  tomatoRating  tomatoReviews  tomatoFresh  \
# 0          NaN          NaN           NaN            NaN          NaN
# 1          NaN          NaN           NaN            NaN          NaN
# 2          NaN          NaN           NaN            NaN          NaN
# 3          NaN          NaN           NaN            NaN          NaN
# 4          NaN          NaN           NaN            NaN          NaN
#
#    tomatoRotten  tomatoConsensus  tomatoUserMeter  tomatoUserRating  \
# 0           NaN              NaN              NaN               NaN
# 1           NaN              NaN              NaN               NaN
# 2           NaN              NaN              NaN               NaN
# 3           NaN              NaN              NaN               NaN
# 4           NaN              NaN              NaN               NaN
#
#    tomatoUserReviews                                          tomatoURL  \
# 0                NaN  http://www.rottentomatoes.com/m/shawshank_rede...
# 1                NaN         http://www.rottentomatoes.com/m/godfather/
# 2                NaN  http://www.rottentomatoes.com/m/godfather_part...
# 3                NaN   http://www.rottentomatoes.com/m/the_dark_knight/
# 4                NaN  http://www.rottentomatoes.com/m/1000013-12_ang...
#
#          DVD     BoxOffice                       Production  \
# 0  27-Jan-98           NaN                Columbia Pictures
# 1  09-Oct-01           NaN               Paramount Pictures
# 2  24-May-05           NaN               Paramount Pictures
# 3  09-Dec-08  $533,316,061  Warner Bros. Pictures/Legendary
# 4  06-Mar-01           NaN             Criterion Collection
#
#                                              Website  Response  \
# 0                                                NaN      True
# 1                        http://www.thegodfather.com      True
# 2                       http://www.thegodfather.com/      True
# 3               http://thedarkknight.warnerbros.com/      True
# 4  http://www.criterion.com/films/27871-12-angry-men      True
#
#                                           clean_plot
# 0  [two, imprisoned, men, bond, over, number, yea...
# 1  [the, aging, patriarch, organized, crime, dyna...
# 2  [the, early, life, and, career, vito, corleone...
# 3  [when, the, menace, known, the, joker, emerges...
# 4  [jury, holdout, attempts, prevent, miscarriage...

# %%
def clean(sentence):
    temp = []
    for word in sentence:
        temp.append(word.lower().replace(' ',''))

# %%
df['Actors'][0]
# Out:
# 'Tim Robbins, Morgan Freeman, Bob Gunton, William Sadler'

# %%
columns = ['clean_plot', 'Genre', 'Actors', 'Director']
l = []
for i in range(len(df)):
    words = ''
    for col in columns:
        words = words + ' '.join(df[col][i]) + ' '
    l.append(words)
l
# Out:
# ['two imprisoned men bond over number years , finding solace and eventual redemption through acts common decency . C r i m e ,   D r a m a T i m   R o b b i n s ,   M o r g a n   F r e e m a n ,   B o b   G u n t o n ,   W i l l i a m   S a d l e r F r a n k   D a r a b o n t ',
#  'the aging patriarch organized crime dynasty transfers control his clandestine empire his reluctant son . C r i m e ,   D r a m a M a r l o n   B r a n d o ,   A l   P a c i n o ,   J a m e s   C a a n ,   R i c h a r d   S .   C a s t e l l a n o F r a n c i s   F o r d   C o p p o l a ',
#  'the early life and career vito corleone 1920s new york portrayed while his son , michael , expands and tightens his grip the family crime syndicate . C r i m e ,   D r a m a A l   P a c i n o ,   R o b e r t   D u v a l l ,   D i a n e   K e a t o n ,   R o b e r t   D e   N i r o F r a n c i s   F o r d   C o p p o l a ',
#  'when the menace known the joker emerges from his mysterious past , wreaks havoc and chaos the people gotham , the dark knight must accept one the greatest psychological and physical tests his ability fight injustice . A c t i o n ,   C r i m e ,   D r a m a C h r i s t i a n   B a l e ,   H e a t h   L e d g e r ,   A a r o n   E c k h a r t ,   M i c h a e l   C a i n e C h r i s t o p h e r   N o l a n ',
#  'old man makes long journey lawn-mover tractor mend his relationship with ill brother . B i o g r a p h y ,   D r a m a S i s s y   S p a c e k ,   J a n e   G a l l o w a y   H e i t z ,   J o s e p h   A .   C a r p e n t e r ,   D o n a l d   W i e g e r t D a v i d   L y n c h ',
#  "mumbai teen reflects his upbringing the slums when accused cheating the indian version `` who wants millionaire ? '' D r a m a D e v   P a t e l ,   S a u r a b h   S h u k l a ,   A n i l   K a p o o r ,   R a j   Z u t s h i D a n n y   B o y l e ,   L o v e l e e n   T a n d a n "]

# %%
df['clean_input'] = l
df = df[['Title', 'clean_input']]
df.head()
# Out:
#                       Title                                        clean_input
# 0  The Shawshank Redemption  two imprisoned men bond over number years , fi...
# 1             The Godfather  the aging patriarch organized crime dynasty tr...
# 2    The Godfather: Part II  the early life and career vito corleone 1920s ...
# 3           The Dark Knight  when the menace known the joker emerges from h...
# 4              12 Angry Men  jury holdout attempts prevent miscarriage just...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tfidf = TfidfVectorizer()
features = tfidf.fit_transform(df['clean_input'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(features, features)
print(cosine_sim)
# Out:
# [[1.         0.         0.01177305 ... 0.         0.         0.        ]
#  [0.         1.         0.12957699 ... 0.02559416 0.0211301  0.03013661]
#  [0.01177305 0.12957699 1.         ... 0.02532208 0.01718246 0.0332349 ]
#  ...
#  [0.         0.02559416 0.02532208 ... 1.         0.00999204 0.01932694]
#  [0.         0.0211301  0.01718246 ... 0.00999204 1.         0.00967014]
#  [0.         0.03013661 0.0332349  ... 0.01932694 0.00967014 1.        ]]

# %%
index = pd.Series(df['Title'])
index.head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                12 Angry Men
# Name: Title, dtype: object

# %%
def recommend_movies(title):
    movies = []
    idx = index[index == title].index[0]
    #print(idx)
    score = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    top10 = list(score.iloc[1:11].index)
    #print(top10)
    
    for i in top10:
        movies.append(df['Title'][i])
    return movies

# %%
recommend_movies('The Dark Knight Rises')
# Out:
# ['The Dark Knight',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Batman Begins',
#  'Star Wars: Episode IV - A New Hope',
#  'Star Wars: Episode VI - Return of the Jedi',
#  'Django Unchained',
#  'The Lord of the Rings: The Two Towers',
#  'Goodfellas',
#  'Full Metal Jacket',
#  'The Grapes of Wrath']

# %%
index[index == 'The Dark Knight Rises'].index[0]
# Out:
# 51

# %%
pd.Series(cosine_sim[51]).sort_values(ascending=False)
# Out:
# 51     1.000000
# 3      0.240885
# 9      0.193405
# 89     0.166764
# 17     0.146024
#          ...
# 110    0.000000
# 218    0.000000
# 216    0.000000
# 25     0.000000
# 83     0.000000
# Length: 250, dtype: float64

# %%
recommend_movies('The Matrix')
# Out:
# ['2001: A Space Odyssey',
#  'The Wolf of Wall Street',
#  "One Flew Over the Cuckoo's Nest",
#  'Alien',
#  'The Dark Knight',
#  'Gandhi',
#  'Network',
#  'Spotlight',
#  'To Kill a Mockingbird',
#  'Arsenic and Old Lace']
